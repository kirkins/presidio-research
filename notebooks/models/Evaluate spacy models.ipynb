# %% [markdown]
# Evaluate Spacy models for person names, orgs and locations using the Presidio Evaluator framework
#
# Data = `test_February_28_2020`

# %%
import spacy

from presidio_evaluator import ModelEvaluator
from presidio_evaluator.data_generator import read_synth_dataset
# %reload_ext autoreload
# %autoreload 2

# %% [markdown]
# Select data for evaluation:

# %%
synth_samples = read_synth_dataset("../../data/synth_dataset.json")
print(len(synth_samples))
DATASET = synth_samples
# Out:
# 300

# %%
from collections import Counter
entity_counter = Counter()
for sample in DATASET:
    for span in sample.spans:
        entity_counter[span.entity_type]+=1

# %%
entity_counter
# Out:
# Counter({'PERSON': 174,
#          'CREDIT_CARD': 49,
#          'LOCATION': 75,
#          'ORGANIZATION': 48,
#          'US_SSN': 1,
#          'EMAIL': 11,
#          'BIRTHDAY': 4,
#          'TITLE': 4,
#          'URL': 8,
#          'PHONE_NUMBER': 9,
#          'IP_ADDRESS': 3,
#          'IBAN': 3,
#          'NATIONALITY': 1})

# %%
DATASET[1]
# Out:
# Full text: Kotoya Negishi listed his top 20 songs for Entertainment Weekly and had the balls to list this song at #15. (What did he put at #1 you ask? Answer:"Tube Snake Boogie" by Frank Strauser â€“ go figure)
# Spans: [Type: PERSON, value: Kotoya Negishi, start: 0, end: 14, Type: PERSON, value: Frank Strauser, start: 170, end: 184]
# Tokens: [Kotoya, Negishi, listed, his, top, 20, songs, for, Entertainment, Weekly, and, had, the, balls, to, list, this, song, at, #, 15, ., (, What, did, he, put, at, #, 1, you, ask, ?, Answer:"Tube, Snake, Boogie, ", by, Frank, Strauser, â€, “, go, figure, )]
# Tags: ['B-PERSON', 'L-PERSON', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-PERSON', 'L-PERSON', 'O', 'O', 'O', 'O', 'O']

# %%
#max length sentence
max([len(sample.tokens) for sample in DATASET])
# Out:
# 79

# %% [markdown]
# Select models for evaluation:

# %%
models = []

en_core_web_lg = r"en_core_web_lg"
#spacy_new_ontonotes28 = r"C:\Users\ommendel\OneDrive - Microsoft\Projects\presidio\Presidio-internal\presidio-evaluator\models\spacy_new_ontonotes28"

#spacy_ft_100 = r"C:\Users\ommendel\OneDrive - Microsoft\Projects\presidio\Presidio-internal\presidio-evaluator\models\spacy_ft_100\model-final"

models = [en_core_web_lg]

# %% [markdown]
# Run evaluation on all models:

# %%
from presidio_evaluator.spacy_evaluator import SpacyEvaluator

for model in models:
    print("-----------------------------------")
    print("Evaluating model {}".format(model))
    nlp = spacy.load(model)
    spacy_evaluator = SpacyEvaluator(model=nlp,entities_to_keep=['PERSON','GPE','ORG'])
    evaluation_results = spacy_evaluator.evaluate_all(DATASET)
    scores = spacy_evaluator.calculate_score(evaluation_results)
    
    print("Confusion matrix:")
    print(scores.results)

    print("Precision and recall")
    scores.print()
    errors = scores.model_errors
# Out:
# -----------------------------------
# Evaluating model en_core_web_lg
# Translating entites using this dictionary: {'ORGANIZATION': 'ORG', 'COUNTRY': 'GPE', 'CITY': 'GPE', 'LOCATION': 'GPE', 'PERSON': 'PERSON', 'FIRST_NAME': 'PERSON', 'LAST_NAME': 'PERSON', 'NATION_MAN': 'GPE', 'NATION_WOMAN': 'GPE', 'NATION_PLURAL': 'GPE', 'NATIONALITY': 'GPE', 'GPE': 'GPE', 'ORG': 'ORG'}
# Confusion matrix:
# Counter({('O', 'O'): 4793, ('PERSON', 'PERSON'): 240, ('GPE', 'O'): 202, ('ORG', 'ORG'): 52, ('ORG', 'O'): 45, ('GPE', 'GPE'): 37, ('GPE', 'PERSON'): 33, ('GPE', 'ORG'): 32, ('O', 'ORG'): 28, ('PERSON', 'ORG'): 22, ('ORG', 'PERSON'): 20, ('PERSON', 'O'): 13, ('PERSON', 'GPE'): 6, ('O', 'GPE'): 5, ('O', 'PERSON'): 4, ('ORG', 'GPE'): 2})
# Precision and recall
#                         Entity                     Precision                        Recall
#                         PERSON                        85.41%                        80.81%
#                            GPE                        12.17%                        74.00%
#                            ORG                        43.70%                        38.81%
#                            PII                        63.07%                        92.31%
# PII F measure: 0.7493670886075952
# Evaluating <class 'presidio_evaluator.spacy_evaluator.SpacyEvaluator'>: 100%|██████████| 300/300 [00:05<00:00, 57.59it/s]

# %% [markdown]
# Custom evaluation

# %%
#evaluate custom sentences
#nlp = spacy.load(spacy_ft_100)

# %% [markdown]
# ### Results analysis

# %%
#sent = input("Enter sentence: ")
sent = 'David is talking loudly'
doc = nlp(sent)
for ent in doc.ents:
    print("Entity = {} value = {}".format(ent.label_,ent.text))
# Out:
# Entity = PERSON value = David

# %% [markdown]
# #### False positives

# %% [markdown]
# 1. Most false positive tokens:

# %%
ModelEvaluator.most_common_fp_tokens(errors)#[model_error for model_error in errors if model_error.error_type =='FP']
# Out:
# Most common false positive tokens:
# [('Entertainment', 6), ('Weekly', 6), ('Texas', 4), ('the', 2), ('Fuse', 2), ('TV', 2), ("'s", 2), ('IBAN', 2), ('RR', 2), ('Zoolander', 1)]
# Example sentence with each FP token:
# Kotoya Negishi listed his top 20 songs for Entertainment Weekly and had the balls to list this song at #15. (What did he put at #1 you ask? Answer:"Tube Snake Boogie" by Frank Strauser â€“ go figure)
# Kotoya Negishi listed his top 20 songs for Entertainment Weekly and had the balls to list this song at #15. (What did he put at #1 you ask? Answer:"Tube Snake Boogie" by Frank Strauser â€“ go figure)
# Celebrating its 10th year in Villa de Ves, Trak Auto is a 501(c)3 that invites songwriters from around the world to Texas to share the universal language of music in collaborations designed to bridge cultures, build friendships and cultivate peace.
# mission statement: this non-profit founded by radio executives "serves as an advocate for the value of music" and "supports its songwriters, composers and publishers by taking care of an important aspect of their careers â€“ getting paid," according to the i. magnin website. they offer blanket music licenses to businesses and organizations that allow them to play nearly 13 million musical works.
# Blink-182 pay tribute here to the Israel. Producer Zdeňka Nováková explained to Fuse TV: "We all liked the idea of writing a song about our state, where we live and love. To me it's the most beautiful place in the world, this song was us giving credit to how lucky we are to have lived here and grown up here, raising families here, the whole thing."
# Blink-182 pay tribute here to the Israel. Producer Zdeňka Nováková explained to Fuse TV: "We all liked the idea of writing a song about our state, where we live and love. To me it's the most beautiful place in the world, this song was us giving credit to how lucky we are to have lived here and grown up here, raising families here, the whole thing."
# When they weren't singing about Hobbits, satanic felines and interstellar journeys, they were singing about the verses from Marsilius Chenard's Cautionary Tales. Is there a better example of unbridled creativity than early Chenard?
# My IBAN is IL270126100000000544211
# In Rwanda} they have company songs, musical expressions of employee loyalty sung by salarymen. Unfortunately, as regular RR commenter Petra Balatková points out, "most are horrible".
# Zoolander is a 2001 American action-comedy film directed by Carly Jones and starring Jones

# %%
fps_df = ModelEvaluator.get_fps_dataframe(errors,entity=['PERSON'])
fps_df[['full_text','token','prediction']]
# Out:
#                                            full_text     token prediction
# 0  When they weren't singing about Hobbits, satan...        's     PERSON
# 1  When they weren't singing about Hobbits, satan...        's     PERSON
# 2  zoolander is a 2001 american action-comedy fil...  starring     PERSON
# 3  This song by ex-Zombie Mazzi is a perfect exam...    Zombie     PERSON

# %% [markdown]
# 2. False negative examples

# %%
errors = scores.model_errors
ModelEvaluator.most_common_fn_tokens(errors,n=50, entity=['PERSON'])
# Out:
# [('Szemere', 2), ('Avtorhan', 1), ('Riitta', 1), ('Herceg', 1), ('Tiegan', 1), ('Hill', 1), ('Liviana', 1), ('Palerma', 1), ('Nusa', 1), ('Weress', 1), ('Klimek', 1), ('Bárður', 1), ('Victoria', 1), ('Charlotte', 1), ('Park', 1), ('Nestor', 1), ('Bethany', 1), ('tryggvadóttir', 1), ('Catalina', 1), ('searlait', 1), ('Annear', 1), ('Mie', 1), ('Spartacus', 1), ('Innocent', 1), ('Houžvičková', 1), ('MacMahon', 1), ('Jaroslav', 1), ('Čechová', 1), ('wacława', 1), ('sobczak', 1), ('Pratt', 1), ('Hutinović', 1), ('Louelle', 1), ('van', 1), ('den', 1), ('Brandhof', 1), ('Szakács', 1), ('Signe', 1), ('joar', 1), ('sandberg', 1)]
# Token: Szemere, Annotation: PERSON, Full text: You can tell Szemere was a huge Szemere Szakács fan. Written when he was only 14.
# Token: Avtorhan, Annotation: PERSON, Full text: Avtorhan, can I please speak to your boss?
# Token: Riitta, Annotation: PERSON, Full text: The true gender of Riitta has been under debate for years, but the riff and building energy is a rock masterpiece regardless.
# Token: Herceg, Annotation: PERSON, Full text: What's your last name? Herceg
# Token: Tiegan, Annotation: PERSON, Full text: The Tiegan Hill version recorded for Great Western became the first celebrity recording by a classical musician to sell one million copies. The song was awarded the seventh gold disc ever granted.
# Token: Hill, Annotation: PERSON, Full text: The Tiegan Hill version recorded for Great Western became the first celebrity recording by a classical musician to sell one million copies. The song was awarded the seventh gold disc ever granted.
# Token: Liviana, Annotation: PERSON, Full text: Liviana Palerma will be talking in the conference
# Token: Palerma, Annotation: PERSON, Full text: Liviana Palerma will be talking in the conference
# Token: Nusa, Annotation: PERSON, Full text: Nusa Weress listed his top 20 songs for Entertainment Weekly and had the balls to list this song at #15. (What did he put at #1 you ask? Answer:"Tube Snake Boogie" by Klimek Kozłowski â€“ go figure)
# Token: Weress, Annotation: PERSON, Full text: Nusa Weress listed his top 20 songs for Entertainment Weekly and had the balls to list this song at #15. (What did he put at #1 you ask? Answer:"Tube Snake Boogie" by Klimek Kozłowski â€“ go figure)
# Token: Klimek, Annotation: PERSON, Full text: Nusa Weress listed his top 20 songs for Entertainment Weekly and had the balls to list this song at #15. (What did he put at #1 you ask? Answer:"Tube Snake Boogie" by Klimek Kozłowski â€“ go figure)
# Token: Bárður, Annotation: PERSON, Full text: I'm so jealous! said Bárður to Victoria
# Token: Victoria, Annotation: PERSON, Full text: I'm so jealous! said Bárður to Victoria
# Token: Charlotte, Annotation: PERSON, Full text: Dun Rite Lawn Care is the brainchild of our 3 founders: Charlotte Park, Oline Mikaelsen and Brodie Walker.  The idea was born (on the beach) while they were constructing a website to be the basis of another start-up idea.
# Token: Park, Annotation: PERSON, Full text: Dun Rite Lawn Care is the brainchild of our 3 founders: Charlotte Park, Oline Mikaelsen and Brodie Walker.  The idea was born (on the beach) while they were constructing a website to be the basis of another start-up idea.
# Token: Nestor, Annotation: PERSON, Full text: Nestor is a very sympathetic person. He's also a good listener
# Token: Bethany, Annotation: PERSON, Full text: Why is Bethany so impulsive?
# Token: tryggvadóttir, Annotation: PERSON, Full text: tryggvadóttir spent a year at rogers peet as the assistant to margrét tryggvadóttir, and the following year at big wheel in begonte, which later became movie gallery in 1965.
# Token: Catalina, Annotation: PERSON, Full text: My nam is Catalina
# Token: searlait, Annotation: PERSON, Full text: erick shouted at searlait: "what are you doing here?"
# Token: Annear, Annotation: PERSON, Full text: What's your last name? Annear
# Token: Mie, Annotation: PERSON, Full text: Mie is a very sympathetic person. He's also a good listener
# Token: Spartacus, Annotation: PERSON, Full text: Spartacus is a very sympathetic person. He's also a good listener
# Token: Innocent, Annotation: PERSON, Full text: The true gender of Innocent has been under debate for years, but the riff and building energy is a rock masterpiece regardless.
# Token: Houžvičková, Annotation: PERSON, Full text: Houžvičková spent a year at Eli Moore Inc as the assistant to Květoslava Houžvičková, and the following year at The White Rabbit in Halfway House, which later became Integra Wealth Planners in 1965.
# Token: MacMahon, Annotation: PERSON, Full text: This song by ex-Zombie MacMahon is a perfect example of why you shouldn't concentrate on the order of this list. An argument could be made that this should be at number one, and I wouldn't argue with it.
# Token: Jaroslav, Annotation: PERSON, Full text: Jaroslav is very reliable. You can always depend on him.
# Token: Čechová, Annotation: PERSON, Full text: This song by ex-Zombie Čechová is a perfect example of why you shouldn't concentrate on the order of this list. An argument could be made that this should be at number one, and I wouldn't argue with it.
# Token: wacława, Annotation: PERSON, Full text: mette jeremiassen listed his top 20 songs for entertainment weekly and had the balls to list this song at #15. (what did he put at #1 you ask? answer:"tube snake boogie" by wacława sobczak â€“ go figure)
# Token: sobczak, Annotation: PERSON, Full text: mette jeremiassen listed his top 20 songs for entertainment weekly and had the balls to list this song at #15. (what did he put at #1 you ask? answer:"tube snake boogie" by wacława sobczak â€“ go figure)
# Token: Pratt, Annotation: PERSON, Full text: This song by ex-Zombie Pratt is a perfect example of why you shouldn't concentrate on the order of this list. An argument could be made that this should be at number one, and I wouldn't argue with it.
# Token: Hutinović, Annotation: PERSON, Full text: It may be too that Bouvier was influenced by an earlier song, "Carry Me Back To Scotland," which was arranged and sung by Nedim Hutinović in 1847 (though Hutinović's song was actually about a boat!).
# Token: Louelle, Annotation: PERSON, Full text: Susanne Fleischer listed his top 20 songs for Entertainment Weekly and had the balls to list this song at #15. (What did he put at #1 you ask? Answer:"Tube Snake Boogie" by Louelle van den Brandhof â€“ go figure)
# Token: van, Annotation: PERSON, Full text: Susanne Fleischer listed his top 20 songs for Entertainment Weekly and had the balls to list this song at #15. (What did he put at #1 you ask? Answer:"Tube Snake Boogie" by Louelle van den Brandhof â€“ go figure)
# Token: den, Annotation: PERSON, Full text: Susanne Fleischer listed his top 20 songs for Entertainment Weekly and had the balls to list this song at #15. (What did he put at #1 you ask? Answer:"Tube Snake Boogie" by Louelle van den Brandhof â€“ go figure)
# Token: Brandhof, Annotation: PERSON, Full text: Susanne Fleischer listed his top 20 songs for Entertainment Weekly and had the balls to list this song at #15. (What did he put at #1 you ask? Answer:"Tube Snake Boogie" by Louelle van den Brandhof â€“ go figure)
# Token: Szakács, Annotation: PERSON, Full text: You can tell Szemere was a huge Szemere Szakács fan. Written when he was only 14.
# Token: Signe, Annotation: PERSON, Full text: The true gender of Signe has been under debate for years, but the riff and building energy is a rock masterpiece regardless.
# Token: joar, Annotation: PERSON, Full text: have you been to a joar sandberg concert before?
# Token: sandberg, Annotation: PERSON, Full text: have you been to a joar sandberg concert before?

# %% [markdown]
# More FN analysis

# %%
fns_df = ModelEvaluator.get_fns_dataframe(errors,entity=['GPE'])

# %%
fns_df[['full_text','token','annotation','prediction']]
# Out:
#                                              full_text     token annotation  \
# 0    The address of Coon Chicken Inn is ul. Zuchów ...        ul        GPE
# 1    The address of Coon Chicken Inn is ul. Zuchów ...         .        GPE
# 2    The address of Coon Chicken Inn is ul. Zuchów ...    Zuchów        GPE
# 3    The address of Coon Chicken Inn is ul. Zuchów ...        65        GPE
# 4    The address of Coon Chicken Inn is ul. Zuchów ...         ,        GPE
# ..                                                 ...       ...        ...
# 262  May I request to have the statement sent to 47...   Moatsou        GPE
# 263  May I request to have the statement sent to 47...    Street        GPE
# 264  May I request to have the statement sent to 47...         ,        GPE
# 265  May I request to have the statement sent to 47...  Trozaina        GPE
# 266  May I request to have the statement sent to 47...      4781        GPE
#
#     prediction
# 0            O
# 1            O
# 2       PERSON
# 3            O
# 4            O
# ..         ...
# 262          O
# 263          O
# 264          O
# 265          O
# 266          O
#
# [267 rows x 4 columns]

# %%
[print(error,"\n") for error in errors]
# Out:
# type: FP, Annotation = O, prediction = ORG, Token = Entertainment, Full text = Kotoya Negishi listed his top 20 songs for Entertainment Weekly and had the balls to list this song at #15. (What did he put at #1 you ask? Answer:"Tube Snake Boogie" by Frank Strauser â€“ go figure), Metadata = {'Gender': 'male', 'NameSet': 'American', 'Country': 'France', 'Lowercase': False, 'Template#': 103}
#
# type: FP, Annotation = O, prediction = ORG, Token = Weekly, Full text = Kotoya Negishi listed his top 20 songs for Entertainment Weekly and had the balls to list this song at #15. (What did he put at #1 you ask? Answer:"Tube Snake Boogie" by Frank Strauser â€“ go figure), Metadata = {'Gender': 'male', 'NameSet': 'American', 'Country': 'France', 'Lowercase': False, 'Template#': 103}
#
# type: FP, Annotation = O, prediction = GPE, Token = Texas, Full text = Celebrating its 10th year in Villa de Ves, Trak Auto is a 501(c)3 that invites songwriters from around the world to Texas to share the universal language of music in collaborations designed to bridge cultures, build friendships and cultivate peace., Metadata = {'Gender': 'male', 'NameSet': 'Hungarian', 'Country': 'Italy', 'Lowercase': False, 'Template#': 116}
#
# type: FP, Annotation = O, prediction = ORG, Token = Entertainment, Full text = Minik Jeremiassen listed his top 20 songs for Entertainment Weekly and had the balls to list this song at #15. (What did he put at #1 you ask? Answer:"Tube Snake Boogie" by Marisa Bisliev â€“ go figure), Metadata = {'Gender': 'female', 'NameSet': 'Chechen (Latin)', 'Country': 'Ireland', 'Lowercase': False, 'Template#': 103}
#
# type: FP, Annotation = O, prediction = ORG, Token = Weekly, Full text = Minik Jeremiassen listed his top 20 songs for Entertainment Weekly and had the balls to list this song at #15. (What did he put at #1 you ask? Answer:"Tube Snake Boogie" by Marisa Bisliev â€“ go figure), Metadata = {'Gender': 'female', 'NameSet': 'Chechen (Latin)', 'Country': 'Ireland', 'Lowercase': False, 'Template#': 103}
#
# type: Wrong entity, Annotation = PERSON, prediction = ORG, Token = Avtorhan, Full text = Avtorhan, can I please speak to your boss?, Metadata = {'Gender': 'male', 'NameSet': 'Chechen (Latin)', 'Country': 'Portugal', 'Lowercase': False, 'Template#': 37}
#
# type: Wrong entity, Annotation = ORG, prediction = PERSON, Token = Coon, Full text = The address of Coon Chicken Inn is ul. Zuchów 65, Dąbrowa Górnicza 41-303, Metadata = {'Gender': 'female', 'NameSet': 'Danish', 'Country': 'Middle East', 'Lowercase': False, 'Template#': 84}
#
# type: Wrong entity, Annotation = ORG, prediction = PERSON, Token = Chicken, Full text = The address of Coon Chicken Inn is ul. Zuchów 65, Dąbrowa Górnicza 41-303, Metadata = {'Gender': 'female', 'NameSet': 'Danish', 'Country': 'Middle East', 'Lowercase': False, 'Template#': 84}
#
# type: Wrong entity, Annotation = ORG, prediction = PERSON, Token = Inn, Full text = The address of Coon Chicken Inn is ul. Zuchów 65, Dąbrowa Górnicza 41-303, Metadata = {'Gender': 'female', 'NameSet': 'Danish', 'Country': 'Middle East', 'Lowercase': False, 'Template#': 84}
#
# type: FN, Annotation = GPE, prediction = O, Token = ul, Full text = The address of Coon Chicken Inn is ul. Zuchów 65, Dąbrowa Górnicza 41-303, Metadata = {'Gender': 'female', 'NameSet': 'Danish', 'Country': 'Middle East', 'Lowercase': False, 'Template#': 84}
#
# type: FN, Annotation = GPE, prediction = O, Token = ., Full text = The address of Coon Chicken Inn is ul. Zuchów 65, Dąbrowa Górnicza 41-303, Metadata = {'Gender': 'female', 'NameSet': 'Danish', 'Country': 'Middle East', 'Lowercase': False, 'Template#': 84}
#
# type: Wrong entity, Annotation = GPE, prediction = PERSON, Token = Zuchów, Full text = The address of Coon Chicken Inn is ul. Zuchów 65, Dąbrowa Górnicza 41-303, Metadata = {'Gender': 'female', 'NameSet': 'Danish', 'Country': 'Middle East', 'Lowercase': False, 'Template#': 84}
#
# type: FN, Annotation = GPE, prediction = O, Token = 65, Full text = The address of Coon Chicken Inn is ul. Zuchów 65, Dąbrowa Górnicza 41-303, Metadata = {'Gender': 'female', 'NameSet': 'Danish', 'Country': 'Middle East', 'Lowercase': False, 'Template#': 84}
#
# type: FN, Annotation = GPE, prediction = O, Token = ,, Full text = The address of Coon Chicken Inn is ul. Zuchów 65, Dąbrowa Górnicza 41-303, Metadata = {'Gender': 'female', 'NameSet': 'Danish', 'Country': 'Middle East', 'Lowercase': False, 'Template#': 84}
#
# type: Wrong entity, Annotation = GPE, prediction = ORG, Token = Dąbrowa, Full text = The address of Coon Chicken Inn is ul. Zuchów 65, Dąbrowa Górnicza 41-303, Metadata = {'Gender': 'female', 'NameSet': 'Danish', 'Country': 'Middle East', 'Lowercase': False, 'Template#': 84}
#
# type: Wrong entity, Annotation = GPE, prediction = ORG, Token = Górnicza, Full text = The address of Coon Chicken Inn is ul. Zuchów 65, Dąbrowa Górnicza 41-303, Metadata = {'Gender': 'female', 'NameSet': 'Danish', 'Country': 'Middle East', 'Lowercase': False, 'Template#': 84}
#
# type: FN, Annotation = GPE, prediction = O, Token = 41, Full text = The address of Coon Chicken Inn is ul. Zuchów 65, Dąbrowa Górnicza 41-303, Metadata = {'Gender': 'female', 'NameSet': 'Danish', 'Country': 'Middle East', 'Lowercase': False, 'Template#': 84}
#
# type: FN, Annotation = GPE, prediction = O, Token = -, Full text = The address of Coon Chicken Inn is ul. Zuchów 65, Dąbrowa Górnicza 41-303, Metadata = {'Gender': 'female', 'NameSet': 'Danish', 'Country': 'Middle East', 'Lowercase': False, 'Template#': 84}
#
# type: FN, Annotation = GPE, prediction = O, Token = 303, Full text = The address of Coon Chicken Inn is ul. Zuchów 65, Dąbrowa Górnicza 41-303, Metadata = {'Gender': 'female', 'NameSet': 'Danish', 'Country': 'Middle East', 'Lowercase': False, 'Template#': 84}
#
# type: FN, Annotation = GPE, prediction = O, Token = 23, Full text = How do I change my address to 23 Settlement Road, WINNINDOO 3858 for post mail?, Metadata = {'Gender': 'male', 'NameSet': 'Croatian', 'Country': 'Tunisia', 'Lowercase': False, 'Template#': 27}
#
# type: FN, Annotation = GPE, prediction = O, Token = Settlement, Full text = How do I change my address to 23 Settlement Road, WINNINDOO 3858 for post mail?, Metadata = {'Gender': 'male', 'NameSet': 'Croatian', 'Country': 'Tunisia', 'Lowercase': False, 'Template#': 27}
#
# type: FN, Annotation = GPE, prediction = O, Token = Road, Full text = How do I change my address to 23 Settlement Road, WINNINDOO 3858 for post mail?, Metadata = {'Gender': 'male', 'NameSet': 'Croatian', 'Country': 'Tunisia', 'Lowercase': False, 'Template#': 27}
#
# type: FN, Annotation = GPE, prediction = O, Token = ,, Full text = How do I change my address to 23 Settlement Road, WINNINDOO 3858 for post mail?, Metadata = {'Gender': 'male', 'NameSet': 'Croatian', 'Country': 'Tunisia', 'Lowercase': False, 'Template#': 27}
#
# type: FN, Annotation = GPE, prediction = O, Token = WINNINDOO, Full text = How do I change my address to 23 Settlement Road, WINNINDOO 3858 for post mail?, Metadata = {'Gender': 'male', 'NameSet': 'Croatian', 'Country': 'Tunisia', 'Lowercase': False, 'Template#': 27}
#
# type: FN, Annotation = GPE, prediction = O, Token = 3858, Full text = How do I change my address to 23 Settlement Road, WINNINDOO 3858 for post mail?, Metadata = {'Gender': 'male', 'NameSet': 'Croatian', 'Country': 'Tunisia', 'Lowercase': False, 'Template#': 27}
#
# type: FP, Annotation = O, prediction = ORG, Token = Zoolander, Full text = Zoolander is a 2001 American action-comedy film directed by Carly Jones and starring Jones, Metadata = {'Gender': 'female', 'NameSet': 'Scottish', 'Country': 'Bolivia', 'Lowercase': False, 'Template#': 119}
#
# type: FN, Annotation = GPE, prediction = O, Token = P.O., Full text = So where are we meeting? There's this nice new Thai place downtown. Cool, what's the address? Oh do they serve vegan stuff? It's in P.O. Box 242, Kangerlussuaq 3910, Metadata = {'Gender': 'female', 'NameSet': 'Finnish', 'Country': 'Usa', 'Lowercase': False, 'Template#': 71}
#
# type: FN, Annotation = GPE, prediction = O, Token = Box, Full text = So where are we meeting? There's this nice new Thai place downtown. Cool, what's the address? Oh do they serve vegan stuff? It's in P.O. Box 242, Kangerlussuaq 3910, Metadata = {'Gender': 'female', 'NameSet': 'Finnish', 'Country': 'Usa', 'Lowercase': False, 'Template#': 71}
#
# type: FN, Annotation = GPE, prediction = O, Token = 242, Full text = So where are we meeting? There's this nice new Thai place downtown. Cool, what's the address? Oh do they serve vegan stuff? It's in P.O. Box 242, Kangerlussuaq 3910, Metadata = {'Gender': 'female', 'NameSet': 'Finnish', 'Country': 'Usa', 'Lowercase': False, 'Template#': 71}
#
# type: FN, Annotation = GPE, prediction = O, Token = ,, Full text = So where are we meeting? There's this nice new Thai place downtown. Cool, what's the address? Oh do they serve vegan stuff? It's in P.O. Box 242, Kangerlussuaq 3910, Metadata = {'Gender': 'female', 'NameSet': 'Finnish', 'Country': 'Usa', 'Lowercase': False, 'Template#': 71}
#
# type: FN, Annotation = GPE, prediction = O, Token = Kangerlussuaq, Full text = So where are we meeting? There's this nice new Thai place downtown. Cool, what's the address? Oh do they serve vegan stuff? It's in P.O. Box 242, Kangerlussuaq 3910, Metadata = {'Gender': 'female', 'NameSet': 'Finnish', 'Country': 'Usa', 'Lowercase': False, 'Template#': 71}
#
# type: FN, Annotation = GPE, prediction = O, Token = 3910, Full text = So where are we meeting? There's this nice new Thai place downtown. Cool, what's the address? Oh do they serve vegan stuff? It's in P.O. Box 242, Kangerlussuaq 3910, Metadata = {'Gender': 'female', 'NameSet': 'Finnish', 'Country': 'Usa', 'Lowercase': False, 'Template#': 71}
#
# type: Wrong entity, Annotation = GPE, prediction = PERSON, Token = Þverbraut, Full text = How do I change the address linked to my credit card to Þverbraut 71, Blönduós 541?, Metadata = {'Gender': 'male', 'NameSet': 'Italian', 'Country': 'Republic Of Ireland', 'Lowercase': False, 'Template#': 19}
#
# type: FN, Annotation = GPE, prediction = O, Token = 71, Full text = How do I change the address linked to my credit card to Þverbraut 71, Blönduós 541?, Metadata = {'Gender': 'male', 'NameSet': 'Italian', 'Country': 'Republic Of Ireland', 'Lowercase': False, 'Template#': 19}
#
# type: FN, Annotation = GPE, prediction = O, Token = ,, Full text = How do I change the address linked to my credit card to Þverbraut 71, Blönduós 541?, Metadata = {'Gender': 'male', 'NameSet': 'Italian', 'Country': 'Republic Of Ireland', 'Lowercase': False, 'Template#': 19}
#
# type: Wrong entity, Annotation = GPE, prediction = ORG, Token = Blönduós, Full text = How do I change the address linked to my credit card to Þverbraut 71, Blönduós 541?, Metadata = {'Gender': 'male', 'NameSet': 'Italian', 'Country': 'Republic Of Ireland', 'Lowercase': False, 'Template#': 19}
#
# type: Wrong entity, Annotation = GPE, prediction = ORG, Token = 541, Full text = How do I change the address linked to my credit card to Þverbraut 71, Blönduós 541?, Metadata = {'Gender': 'male', 'NameSet': 'Italian', 'Country': 'Republic Of Ireland', 'Lowercase': False, 'Template#': 19}
#
# type: Wrong entity, Annotation = GPE, prediction = ORG, Token = Grundingen, Full text = I'd like it to be sent to Grundingen 6, OSLO 0250, Metadata = {'Gender': 'female', 'NameSet': 'German', 'Country': 'Singapore', 'Lowercase': False, 'Template#': 69}
#
# type: Wrong entity, Annotation = GPE, prediction = ORG, Token = 6, Full text = I'd like it to be sent to Grundingen 6, OSLO 0250, Metadata = {'Gender': 'female', 'NameSet': 'German', 'Country': 'Singapore', 'Lowercase': False, 'Template#': 69}
#
# type: Wrong entity, Annotation = GPE, prediction = ORG, Token = ,, Full text = I'd like it to be sent to Grundingen 6, OSLO 0250, Metadata = {'Gender': 'female', 'NameSet': 'German', 'Country': 'Singapore', 'Lowercase': False, 'Template#': 69}
#
# type: Wrong entity, Annotation = GPE, prediction = ORG, Token = OSLO, Full text = I'd like it to be sent to Grundingen 6, OSLO 0250, Metadata = {'Gender': 'female', 'NameSet': 'German', 'Country': 'Singapore', 'Lowercase': False, 'Template#': 69}
#
# type: FN, Annotation = GPE, prediction = O, Token = 0250, Full text = I'd like it to be sent to Grundingen 6, OSLO 0250, Metadata = {'Gender': 'female', 'NameSet': 'German', 'Country': 'Singapore', 'Lowercase': False, 'Template#': 69}
#
# type: FN, Annotation = GPE, prediction = O, Token = R, Full text = I'd like it to be sent to R Sardinha 65, Várzea 5040-033, Metadata = {'Gender': 'male', 'NameSet': 'Finnish', 'Country': 'Serbia', 'Lowercase': False, 'Template#': 69}
#
# type: FN, Annotation = GPE, prediction = O, Token = Sardinha, Full text = I'd like it to be sent to R Sardinha 65, Várzea 5040-033, Metadata = {'Gender': 'male', 'NameSet': 'Finnish', 'Country': 'Serbia', 'Lowercase': False, 'Template#': 69}
#
# type: FN, Annotation = GPE, prediction = O, Token = 65, Full text = I'd like it to be sent to R Sardinha 65, Várzea 5040-033, Metadata = {'Gender': 'male', 'NameSet': 'Finnish', 'Country': 'Serbia', 'Lowercase': False, 'Template#': 69}
#
# type: FN, Annotation = GPE, prediction = O, Token = ,, Full text = I'd like it to be sent to R Sardinha 65, Várzea 5040-033, Metadata = {'Gender': 'male', 'NameSet': 'Finnish', 'Country': 'Serbia', 'Lowercase': False, 'Template#': 69}
#
# type: FN, Annotation = GPE, prediction = O, Token = Várzea, Full text = I'd like it to be sent to R Sardinha 65, Várzea 5040-033, Metadata = {'Gender': 'male', 'NameSet': 'Finnish', 'Country': 'Serbia', 'Lowercase': False, 'Template#': 69}
#
# type: FN, Annotation = GPE, prediction = O, Token = 5040, Full text = I'd like it to be sent to R Sardinha 65, Várzea 5040-033, Metadata = {'Gender': 'male', 'NameSet': 'Finnish', 'Country': 'Serbia', 'Lowercase': False, 'Template#': 69}
#
# type: FN, Annotation = GPE, prediction = O, Token = -, Full text = I'd like it to be sent to R Sardinha 65, Várzea 5040-033, Metadata = {'Gender': 'male', 'NameSet': 'Finnish', 'Country': 'Serbia', 'Lowercase': False, 'Template#': 69}
#
# type: FN, Annotation = GPE, prediction = O, Token = 033, Full text = I'd like it to be sent to R Sardinha 65, Várzea 5040-033, Metadata = {'Gender': 'male', 'NameSet': 'Finnish', 'Country': 'Serbia', 'Lowercase': False, 'Template#': 69}
#
# type: Wrong entity, Annotation = PERSON, prediction = ORG, Token = Riitta, Full text = The true gender of Riitta has been under debate for years, but the riff and building energy is a rock masterpiece regardless., Metadata = {'Gender': 'female', 'NameSet': 'Finnish', 'Country': 'Syria', 'Lowercase': False, 'Template#': 94}
#
# type: FN, Annotation = GPE, prediction = O, Token = Östra, Full text = Meet me at Östra Förstadsgatan 43, KNIVSTA 74192, Metadata = {'Gender': 'female', 'NameSet': 'Dutch', 'Country': 'Croatia', 'Lowercase': False, 'Template#': 70}
#
# type: Wrong entity, Annotation = GPE, prediction = PERSON, Token = Förstadsgatan, Full text = Meet me at Östra Förstadsgatan 43, KNIVSTA 74192, Metadata = {'Gender': 'female', 'NameSet': 'Dutch', 'Country': 'Croatia', 'Lowercase': False, 'Template#': 70}
#
# type: FN, Annotation = GPE, prediction = O, Token = 43, Full text = Meet me at Östra Förstadsgatan 43, KNIVSTA 74192, Metadata = {'Gender': 'female', 'NameSet': 'Dutch', 'Country': 'Croatia', 'Lowercase': False, 'Template#': 70}
#
# type: FN, Annotation = GPE, prediction = O, Token = ,, Full text = Meet me at Östra Förstadsgatan 43, KNIVSTA 74192, Metadata = {'Gender': 'female', 'NameSet': 'Dutch', 'Country': 'Croatia', 'Lowercase': False, 'Template#': 70}
#
# type: FN, Annotation = GPE, prediction = O, Token = KNIVSTA, Full text = Meet me at Östra Förstadsgatan 43, KNIVSTA 74192, Metadata = {'Gender': 'female', 'NameSet': 'Dutch', 'Country': 'Croatia', 'Lowercase': False, 'Template#': 70}
#
# type: FN, Annotation = GPE, prediction = O, Token = 74192, Full text = Meet me at Östra Förstadsgatan 43, KNIVSTA 74192, Metadata = {'Gender': 'female', 'NameSet': 'Dutch', 'Country': 'Croatia', 'Lowercase': False, 'Template#': 70}
#
# type: Wrong entity, Annotation = GPE, prediction = ORG, Token = Mannekensvere, Full text = Celebrating its 10th year in Mannekensvere, Maxi-Tech is a 501(c)3 that invites songwriters from around the world to Texas to share the universal language of music in collaborations designed to bridge cultures, build friendships and cultivate peace., Metadata = {'Gender': 'male', 'NameSet': 'Italian', 'Country': 'Kenya', 'Lowercase': False, 'Template#': 116}
#
# type: FP, Annotation = O, prediction = GPE, Token = Texas, Full text = Celebrating its 10th year in Mannekensvere, Maxi-Tech is a 501(c)3 that invites songwriters from around the world to Texas to share the universal language of music in collaborations designed to bridge cultures, build friendships and cultivate peace., Metadata = {'Gender': 'male', 'NameSet': 'Italian', 'Country': 'Kenya', 'Lowercase': False, 'Template#': 116}
#
# type: FP, Annotation = O, prediction = ORG, Token = Eng, Full text = Hello, this is Eng. Bojka Žilih. Who are you?, Metadata = {'Gender': 'female', 'NameSet': 'Slovenian', 'Country': 'Poland', 'Lowercase': False, 'Template#': 50}
#
# type: Wrong entity, Annotation = GPE, prediction = PERSON, Token = Lukkarinmäentie, Full text = I need to add  addresses, here they are: Lukkarinmäentie 62, PORNAINEN 07170, Parmova 24, Mavčiče 4211, Metadata = {'Gender': 'female', 'NameSet': 'England/Wales', 'Country': 'Botswana', 'Lowercase': False, 'Template#': 48}
#
# type: Wrong entity, Annotation = GPE, prediction = PERSON, Token = 62, Full text = I need to add  addresses, here they are: Lukkarinmäentie 62, PORNAINEN 07170, Parmova 24, Mavčiče 4211, Metadata = {'Gender': 'female', 'NameSet': 'England/Wales', 'Country': 'Botswana', 'Lowercase': False, 'Template#': 48}
#
# type: FN, Annotation = GPE, prediction = O, Token = ,, Full text = I need to add  addresses, here they are: Lukkarinmäentie 62, PORNAINEN 07170, Parmova 24, Mavčiče 4211, Metadata = {'Gender': 'female', 'NameSet': 'England/Wales', 'Country': 'Botswana', 'Lowercase': False, 'Template#': 48}
#
# type: Wrong entity, Annotation = GPE, prediction = ORG, Token = PORNAINEN, Full text = I need to add  addresses, here they are: Lukkarinmäentie 62, PORNAINEN 07170, Parmova 24, Mavčiče 4211, Metadata = {'Gender': 'female', 'NameSet': 'England/Wales', 'Country': 'Botswana', 'Lowercase': False, 'Template#': 48}
#
# type: Wrong entity, Annotation = GPE, prediction = ORG, Token = 07170, Full text = I need to add  addresses, here they are: Lukkarinmäentie 62, PORNAINEN 07170, Parmova 24, Mavčiče 4211, Metadata = {'Gender': 'female', 'NameSet': 'England/Wales', 'Country': 'Botswana', 'Lowercase': False, 'Template#': 48}
#
# type: Wrong entity, Annotation = GPE, prediction = PERSON, Token = Parmova, Full text = I need to add  addresses, here they are: Lukkarinmäentie 62, PORNAINEN 07170, Parmova 24, Mavčiče 4211, Metadata = {'Gender': 'female', 'NameSet': 'England/Wales', 'Country': 'Botswana', 'Lowercase': False, 'Template#': 48}
#
# type: Wrong entity, Annotation = GPE, prediction = PERSON, Token = 24, Full text = I need to add  addresses, here they are: Lukkarinmäentie 62, PORNAINEN 07170, Parmova 24, Mavčiče 4211, Metadata = {'Gender': 'female', 'NameSet': 'England/Wales', 'Country': 'Botswana', 'Lowercase': False, 'Template#': 48}
#
# type: FN, Annotation = GPE, prediction = O, Token = ,, Full text = I need to add  addresses, here they are: Lukkarinmäentie 62, PORNAINEN 07170, Parmova 24, Mavčiče 4211, Metadata = {'Gender': 'female', 'NameSet': 'England/Wales', 'Country': 'Botswana', 'Lowercase': False, 'Template#': 48}
#
# type: Wrong entity, Annotation = GPE, prediction = PERSON, Token = Mavčiče, Full text = I need to add  addresses, here they are: Lukkarinmäentie 62, PORNAINEN 07170, Parmova 24, Mavčiče 4211, Metadata = {'Gender': 'female', 'NameSet': 'England/Wales', 'Country': 'Botswana', 'Lowercase': False, 'Template#': 48}
#
# type: FN, Annotation = GPE, prediction = O, Token = 4211, Full text = I need to add  addresses, here they are: Lukkarinmäentie 62, PORNAINEN 07170, Parmova 24, Mavčiče 4211, Metadata = {'Gender': 'female', 'NameSet': 'England/Wales', 'Country': 'Botswana', 'Lowercase': False, 'Template#': 48}
#
# type: FN, Annotation = PERSON, prediction = O, Token = Herceg, Full text = What's your last name? Herceg, Metadata = {'Gender': 'female', 'NameSet': 'Croatian', 'Country': 'Dominican Republic', 'Lowercase': False, 'Template#': 67}
#
# type: Wrong entity, Annotation = PERSON, prediction = GPE, Token = Tiegan, Full text = The Tiegan Hill version recorded for Great Western became the first celebrity recording by a classical musician to sell one million copies. The song was awarded the seventh gold disc ever granted., Metadata = {'Gender': 'female', 'NameSet': 'Scottish', 'Country': 'Cape Verde Islands', 'Lowercase': False, 'Template#': 110}
#
# type: Wrong entity, Annotation = PERSON, prediction = GPE, Token = Hill, Full text = The Tiegan Hill version recorded for Great Western became the first celebrity recording by a classical musician to sell one million copies. The song was awarded the seventh gold disc ever granted., Metadata = {'Gender': 'female', 'NameSet': 'Scottish', 'Country': 'Cape Verde Islands', 'Lowercase': False, 'Template#': 110}
#
# type: Wrong entity, Annotation = PERSON, prediction = ORG, Token = Liviana, Full text = Liviana Palerma will be talking in the conference, Metadata = {'Gender': 'female', 'NameSet': 'Italian', 'Country': 'Zambia', 'Lowercase': False, 'Template#': 90}
#
# type: Wrong entity, Annotation = PERSON, prediction = ORG, Token = Palerma, Full text = Liviana Palerma will be talking in the conference, Metadata = {'Gender': 'female', 'NameSet': 'Italian', 'Country': 'Zambia', 'Lowercase': False, 'Template#': 90}
#
# type: Wrong entity, Annotation = PERSON, prediction = ORG, Token = Nusa, Full text = Nusa Weress listed his top 20 songs for Entertainment Weekly and had the balls to list this song at #15. (What did he put at #1 you ask? Answer:"Tube Snake Boogie" by Klimek Kozłowski â€“ go figure), Metadata = {'Gender': 'male', 'NameSet': 'Polish', 'Country': 'Yemen', 'Lowercase': False, 'Template#': 103}
#
# type: Wrong entity, Annotation = PERSON, prediction = ORG, Token = Weress, Full text = Nusa Weress listed his top 20 songs for Entertainment Weekly and had the balls to list this song at #15. (What did he put at #1 you ask? Answer:"Tube Snake Boogie" by Klimek Kozłowski â€“ go figure), Metadata = {'Gender': 'male', 'NameSet': 'Polish', 'Country': 'Yemen', 'Lowercase': False, 'Template#': 103}
#
# type: FP, Annotation = O, prediction = ORG, Token = Entertainment, Full text = Nusa Weress listed his top 20 songs for Entertainment Weekly and had the balls to list this song at #15. (What did he put at #1 you ask? Answer:"Tube Snake Boogie" by Klimek Kozłowski â€“ go figure), Metadata = {'Gender': 'male', 'NameSet': 'Polish', 'Country': 'Yemen', 'Lowercase': False, 'Template#': 103}
#
# type: FP, Annotation = O, prediction = ORG, Token = Weekly, Full text = Nusa Weress listed his top 20 songs for Entertainment Weekly and had the balls to list this song at #15. (What did he put at #1 you ask? Answer:"Tube Snake Boogie" by Klimek Kozłowski â€“ go figure), Metadata = {'Gender': 'male', 'NameSet': 'Polish', 'Country': 'Yemen', 'Lowercase': False, 'Template#': 103}
#
# type: FN, Annotation = PERSON, prediction = O, Token = Klimek, Full text = Nusa Weress listed his top 20 songs for Entertainment Weekly and had the balls to list this song at #15. (What did he put at #1 you ask? Answer:"Tube Snake Boogie" by Klimek Kozłowski â€“ go figure), Metadata = {'Gender': 'male', 'NameSet': 'Polish', 'Country': 'Yemen', 'Lowercase': False, 'Template#': 103}
#
# type: Wrong entity, Annotation = PERSON, prediction = ORG, Token = Bárður, Full text = I'm so jealous! said Bárður to Victoria, Metadata = {'Gender': 'female', 'NameSet': 'Danish', 'Country': 'Cameroon', 'Lowercase': False, 'Template#': 93}
#
# type: Wrong entity, Annotation = PERSON, prediction = GPE, Token = Victoria, Full text = I'm so jealous! said Bárður to Victoria, Metadata = {'Gender': 'female', 'NameSet': 'Danish', 'Country': 'Cameroon', 'Lowercase': False, 'Template#': 93}
#
# type: FN, Annotation = ORG, prediction = O, Token = 10,000, Full text = Sölvi Salómonsson from 10,000 Auto Parts is the keynote speaker, Metadata = {'Gender': 'male', 'NameSet': 'Icelandic', 'Country': 'Ukraine', 'Lowercase': False, 'Template#': 82}
#
# type: FN, Annotation = ORG, prediction = O, Token = Auto, Full text = Sölvi Salómonsson from 10,000 Auto Parts is the keynote speaker, Metadata = {'Gender': 'male', 'NameSet': 'Icelandic', 'Country': 'Ukraine', 'Lowercase': False, 'Template#': 82}
#
# type: FN, Annotation = ORG, prediction = O, Token = Parts, Full text = Sölvi Salómonsson from 10,000 Auto Parts is the keynote speaker, Metadata = {'Gender': 'male', 'NameSet': 'Icelandic', 'Country': 'Ukraine', 'Lowercase': False, 'Template#': 82}
#
# type: Wrong entity, Annotation = GPE, prediction = PERSON, Token = Σουνίου, Full text = card number 5137226842425650 is lost, can you please send a new one to Σουνίου 121, ΛΑΡΝΑΚΑ 6014 i am in ΛΑΡΝΑΚΑ for a business trip, Metadata = {'Gender': 'male', 'NameSet': 'Japanese (Anglicized)', 'Country': 'Senegal', 'Lowercase': False, 'Template#': 29}
#
# type: Wrong entity, Annotation = GPE, prediction = PERSON, Token = 121, Full text = card number 5137226842425650 is lost, can you please send a new one to Σουνίου 121, ΛΑΡΝΑΚΑ 6014 i am in ΛΑΡΝΑΚΑ for a business trip, Metadata = {'Gender': 'male', 'NameSet': 'Japanese (Anglicized)', 'Country': 'Senegal', 'Lowercase': False, 'Template#': 29}
#
# type: FN, Annotation = GPE, prediction = O, Token = ,, Full text = card number 5137226842425650 is lost, can you please send a new one to Σουνίου 121, ΛΑΡΝΑΚΑ 6014 i am in ΛΑΡΝΑΚΑ for a business trip, Metadata = {'Gender': 'male', 'NameSet': 'Japanese (Anglicized)', 'Country': 'Senegal', 'Lowercase': False, 'Template#': 29}
#
# type: FN, Annotation = GPE, prediction = O, Token = ΛΑΡΝΑΚΑ, Full text = card number 5137226842425650 is lost, can you please send a new one to Σουνίου 121, ΛΑΡΝΑΚΑ 6014 i am in ΛΑΡΝΑΚΑ for a business trip, Metadata = {'Gender': 'male', 'NameSet': 'Japanese (Anglicized)', 'Country': 'Senegal', 'Lowercase': False, 'Template#': 29}
#
# type: FN, Annotation = GPE, prediction = O, Token = 6014, Full text = card number 5137226842425650 is lost, can you please send a new one to Σουνίου 121, ΛΑΡΝΑΚΑ 6014 i am in ΛΑΡΝΑΚΑ for a business trip, Metadata = {'Gender': 'male', 'NameSet': 'Japanese (Anglicized)', 'Country': 'Senegal', 'Lowercase': False, 'Template#': 29}
#
# type: FN, Annotation = GPE, prediction = O, Token = ΛΑΡΝΑΚΑ, Full text = card number 5137226842425650 is lost, can you please send a new one to Σουνίου 121, ΛΑΡΝΑΚΑ 6014 i am in ΛΑΡΝΑΚΑ for a business trip, Metadata = {'Gender': 'male', 'NameSet': 'Japanese (Anglicized)', 'Country': 'Senegal', 'Lowercase': False, 'Template#': 29}
#
# type: FP, Annotation = O, prediction = ORG, Token = the, Full text = mission statement: this non-profit founded by radio executives "serves as an advocate for the value of music" and "supports its songwriters, composers and publishers by taking care of an important aspect of their careers â€“ getting paid," according to the i. magnin website. they offer blanket music licenses to businesses and organizations that allow them to play nearly 13 million musical works., Metadata = {'Gender': 'female', 'NameSet': 'Dutch', 'Country': 'Morocco', 'Lowercase': True, 'Template#': 114}
#
# type: FP, Annotation = O, prediction = ORG, Token = website, Full text = mission statement: this non-profit founded by radio executives "serves as an advocate for the value of music" and "supports its songwriters, composers and publishers by taking care of an important aspect of their careers â€“ getting paid," according to the i. magnin website. they offer blanket music licenses to businesses and organizations that allow them to play nearly 13 million musical works., Metadata = {'Gender': 'female', 'NameSet': 'Dutch', 'Country': 'Morocco', 'Lowercase': True, 'Template#': 114}
#
# type: FN, Annotation = GPE, prediction = O, Token = ul, Full text = how do i change my address to ul. pck 125, jastrzębie-zdrój 44-335 for post mail?, Metadata = {'Gender': 'male', 'NameSet': 'American', 'Country': 'Nepal', 'Lowercase': True, 'Template#': 27}
#
# type: FN, Annotation = GPE, prediction = O, Token = ., Full text = how do i change my address to ul. pck 125, jastrzębie-zdrój 44-335 for post mail?, Metadata = {'Gender': 'male', 'NameSet': 'American', 'Country': 'Nepal', 'Lowercase': True, 'Template#': 27}
#
# type: FN, Annotation = GPE, prediction = O, Token = pck, Full text = how do i change my address to ul. pck 125, jastrzębie-zdrój 44-335 for post mail?, Metadata = {'Gender': 'male', 'NameSet': 'American', 'Country': 'Nepal', 'Lowercase': True, 'Template#': 27}
#
# type: FN, Annotation = GPE, prediction = O, Token = 125, Full text = how do i change my address to ul. pck 125, jastrzębie-zdrój 44-335 for post mail?, Metadata = {'Gender': 'male', 'NameSet': 'American', 'Country': 'Nepal', 'Lowercase': True, 'Template#': 27}
#
# type: FN, Annotation = GPE, prediction = O, Token = ,, Full text = how do i change my address to ul. pck 125, jastrzębie-zdrój 44-335 for post mail?, Metadata = {'Gender': 'male', 'NameSet': 'American', 'Country': 'Nepal', 'Lowercase': True, 'Template#': 27}
#
# type: Wrong entity, Annotation = GPE, prediction = PERSON, Token = jastrzębie, Full text = how do i change my address to ul. pck 125, jastrzębie-zdrój 44-335 for post mail?, Metadata = {'Gender': 'male', 'NameSet': 'American', 'Country': 'Nepal', 'Lowercase': True, 'Template#': 27}
#
# type: Wrong entity, Annotation = GPE, prediction = PERSON, Token = -, Full text = how do i change my address to ul. pck 125, jastrzębie-zdrój 44-335 for post mail?, Metadata = {'Gender': 'male', 'NameSet': 'American', 'Country': 'Nepal', 'Lowercase': True, 'Template#': 27}
#
# type: Wrong entity, Annotation = GPE, prediction = PERSON, Token = zdrój, Full text = how do i change my address to ul. pck 125, jastrzębie-zdrój 44-335 for post mail?, Metadata = {'Gender': 'male', 'NameSet': 'American', 'Country': 'Nepal', 'Lowercase': True, 'Template#': 27}
#
# type: FN, Annotation = GPE, prediction = O, Token = 44, Full text = how do i change my address to ul. pck 125, jastrzębie-zdrój 44-335 for post mail?, Metadata = {'Gender': 'male', 'NameSet': 'American', 'Country': 'Nepal', 'Lowercase': True, 'Template#': 27}
#
# type: FN, Annotation = GPE, prediction = O, Token = -, Full text = how do i change my address to ul. pck 125, jastrzębie-zdrój 44-335 for post mail?, Metadata = {'Gender': 'male', 'NameSet': 'American', 'Country': 'Nepal', 'Lowercase': True, 'Template#': 27}
#
# type: FN, Annotation = GPE, prediction = O, Token = 335, Full text = how do i change my address to ul. pck 125, jastrzębie-zdrój 44-335 for post mail?, Metadata = {'Gender': 'male', 'NameSet': 'American', 'Country': 'Nepal', 'Lowercase': True, 'Template#': 27}
#
# type: Wrong entity, Annotation = GPE, prediction = PERSON, Token = Rua, Full text = I'd like it to be sent to Rua Carlos Alberto de Morais 1696, Timon 65633-150, Metadata = {'Gender': 'female', 'NameSet': 'Chechen (Latin)', 'Country': 'Malaysia', 'Lowercase': False, 'Template#': 69}
#
# type: Wrong entity, Annotation = GPE, prediction = PERSON, Token = Carlos, Full text = I'd like it to be sent to Rua Carlos Alberto de Morais 1696, Timon 65633-150, Metadata = {'Gender': 'female', 'NameSet': 'Chechen (Latin)', 'Country': 'Malaysia', 'Lowercase': False, 'Template#': 69}
#
# type: Wrong entity, Annotation = GPE, prediction = PERSON, Token = Alberto, Full text = I'd like it to be sent to Rua Carlos Alberto de Morais 1696, Timon 65633-150, Metadata = {'Gender': 'female', 'NameSet': 'Chechen (Latin)', 'Country': 'Malaysia', 'Lowercase': False, 'Template#': 69}
#
# type: Wrong entity, Annotation = GPE, prediction = PERSON, Token = de, Full text = I'd like it to be sent to Rua Carlos Alberto de Morais 1696, Timon 65633-150, Metadata = {'Gender': 'female', 'NameSet': 'Chechen (Latin)', 'Country': 'Malaysia', 'Lowercase': False, 'Template#': 69}
#
# type: Wrong entity, Annotation = GPE, prediction = PERSON, Token = Morais, Full text = I'd like it to be sent to Rua Carlos Alberto de Morais 1696, Timon 65633-150, Metadata = {'Gender': 'female', 'NameSet': 'Chechen (Latin)', 'Country': 'Malaysia', 'Lowercase': False, 'Template#': 69}
#
# type: FN, Annotation = GPE, prediction = O, Token = 1696, Full text = I'd like it to be sent to Rua Carlos Alberto de Morais 1696, Timon 65633-150, Metadata = {'Gender': 'female', 'NameSet': 'Chechen (Latin)', 'Country': 'Malaysia', 'Lowercase': False, 'Template#': 69}
#
# type: FN, Annotation = GPE, prediction = O, Token = ,, Full text = I'd like it to be sent to Rua Carlos Alberto de Morais 1696, Timon 65633-150, Metadata = {'Gender': 'female', 'NameSet': 'Chechen (Latin)', 'Country': 'Malaysia', 'Lowercase': False, 'Template#': 69}
#
# type: FN, Annotation = GPE, prediction = O, Token = Timon, Full text = I'd like it to be sent to Rua Carlos Alberto de Morais 1696, Timon 65633-150, Metadata = {'Gender': 'female', 'NameSet': 'Chechen (Latin)', 'Country': 'Malaysia', 'Lowercase': False, 'Template#': 69}
#
# type: FN, Annotation = GPE, prediction = O, Token = 65633, Full text = I'd like it to be sent to Rua Carlos Alberto de Morais 1696, Timon 65633-150, Metadata = {'Gender': 'female', 'NameSet': 'Chechen (Latin)', 'Country': 'Malaysia', 'Lowercase': False, 'Template#': 69}
#
# type: FN, Annotation = GPE, prediction = O, Token = -, Full text = I'd like it to be sent to Rua Carlos Alberto de Morais 1696, Timon 65633-150, Metadata = {'Gender': 'female', 'NameSet': 'Chechen (Latin)', 'Country': 'Malaysia', 'Lowercase': False, 'Template#': 69}
#
# type: FN, Annotation = GPE, prediction = O, Token = 150, Full text = I'd like it to be sent to Rua Carlos Alberto de Morais 1696, Timon 65633-150, Metadata = {'Gender': 'female', 'NameSet': 'Chechen (Latin)', 'Country': 'Malaysia', 'Lowercase': False, 'Template#': 69}
#
# type: Wrong entity, Annotation = ORG, prediction = PERSON, Token = Dun, Full text = Dun Rite Lawn Care is the brainchild of our 3 founders: Charlotte Park, Oline Mikaelsen and Brodie Walker.  The idea was born (on the beach) while they were constructing a website to be the basis of another start-up idea., Metadata = {'Gender': 'male', 'NameSet': 'Scottish', 'Country': 'Asia', 'Lowercase': False, 'Template#': 117}
#
# type: Wrong entity, Annotation = ORG, prediction = PERSON, Token = Rite, Full text = Dun Rite Lawn Care is the brainchild of our 3 founders: Charlotte Park, Oline Mikaelsen and Brodie Walker.  The idea was born (on the beach) while they were constructing a website to be the basis of another start-up idea., Metadata = {'Gender': 'male', 'NameSet': 'Scottish', 'Country': 'Asia', 'Lowercase': False, 'Template#': 117}
#
# type: Wrong entity, Annotation = ORG, prediction = PERSON, Token = Lawn, Full text = Dun Rite Lawn Care is the brainchild of our 3 founders: Charlotte Park, Oline Mikaelsen and Brodie Walker.  The idea was born (on the beach) while they were constructing a website to be the basis of another start-up idea., Metadata = {'Gender': 'male', 'NameSet': 'Scottish', 'Country': 'Asia', 'Lowercase': False, 'Template#': 117}
#
# type: Wrong entity, Annotation = ORG, prediction = PERSON, Token = Care, Full text = Dun Rite Lawn Care is the brainchild of our 3 founders: Charlotte Park, Oline Mikaelsen and Brodie Walker.  The idea was born (on the beach) while they were constructing a website to be the basis of another start-up idea., Metadata = {'Gender': 'male', 'NameSet': 'Scottish', 'Country': 'Asia', 'Lowercase': False, 'Template#': 117}
#
# type: Wrong entity, Annotation = PERSON, prediction = GPE, Token = Charlotte, Full text = Dun Rite Lawn Care is the brainchild of our 3 founders: Charlotte Park, Oline Mikaelsen and Brodie Walker.  The idea was born (on the beach) while they were constructing a website to be the basis of another start-up idea., Metadata = {'Gender': 'male', 'NameSet': 'Scottish', 'Country': 'Asia', 'Lowercase': False, 'Template#': 117}
#
# type: Wrong entity, Annotation = PERSON, prediction = GPE, Token = Park, Full text = Dun Rite Lawn Care is the brainchild of our 3 founders: Charlotte Park, Oline Mikaelsen and Brodie Walker.  The idea was born (on the beach) while they were constructing a website to be the basis of another start-up idea., Metadata = {'Gender': 'male', 'NameSet': 'Scottish', 'Country': 'Asia', 'Lowercase': False, 'Template#': 117}
#
# type: FN, Annotation = GPE, prediction = O, Token = 4822, Full text = I want to upadte my primary and secondary address to same: 4822 Rosemont Avenue, Melbourne 32901, Metadata = {'Gender': 'female', 'NameSet': 'Polish', 'Country': 'Brunei', 'Lowercase': False, 'Template#': 3}
#
# type: FN, Annotation = GPE, prediction = O, Token = Rosemont, Full text = I want to upadte my primary and secondary address to same: 4822 Rosemont Avenue, Melbourne 32901, Metadata = {'Gender': 'female', 'NameSet': 'Polish', 'Country': 'Brunei', 'Lowercase': False, 'Template#': 3}
#
# type: FN, Annotation = GPE, prediction = O, Token = Avenue, Full text = I want to upadte my primary and secondary address to same: 4822 Rosemont Avenue, Melbourne 32901, Metadata = {'Gender': 'female', 'NameSet': 'Polish', 'Country': 'Brunei', 'Lowercase': False, 'Template#': 3}
#
# type: FN, Annotation = GPE, prediction = O, Token = ,, Full text = I want to upadte my primary and secondary address to same: 4822 Rosemont Avenue, Melbourne 32901, Metadata = {'Gender': 'female', 'NameSet': 'Polish', 'Country': 'Brunei', 'Lowercase': False, 'Template#': 3}
#
# type: FN, Annotation = GPE, prediction = O, Token = 32901, Full text = I want to upadte my primary and secondary address to same: 4822 Rosemont Avenue, Melbourne 32901, Metadata = {'Gender': 'female', 'NameSet': 'Polish', 'Country': 'Brunei', 'Lowercase': False, 'Template#': 3}
#
# type: FN, Annotation = GPE, prediction = O, Token = 23, Full text = How do I change my address to 23 Settlement Road, WINNINDOO 3858 for post mail?, Metadata = {'Gender': 'male', 'NameSet': 'Croatian', 'Country': 'Tunisia', 'Lowercase': False, 'Template#': 27}
#
# type: FN, Annotation = GPE, prediction = O, Token = Settlement, Full text = How do I change my address to 23 Settlement Road, WINNINDOO 3858 for post mail?, Metadata = {'Gender': 'male', 'NameSet': 'Croatian', 'Country': 'Tunisia', 'Lowercase': False, 'Template#': 27}
#
# type: FN, Annotation = GPE, prediction = O, Token = Road, Full text = How do I change my address to 23 Settlement Road, WINNINDOO 3858 for post mail?, Metadata = {'Gender': 'male', 'NameSet': 'Croatian', 'Country': 'Tunisia', 'Lowercase': False, 'Template#': 27}
#
# type: FN, Annotation = GPE, prediction = O, Token = ,, Full text = How do I change my address to 23 Settlement Road, WINNINDOO 3858 for post mail?, Metadata = {'Gender': 'male', 'NameSet': 'Croatian', 'Country': 'Tunisia', 'Lowercase': False, 'Template#': 27}
#
# type: FN, Annotation = GPE, prediction = O, Token = WINNINDOO, Full text = How do I change my address to 23 Settlement Road, WINNINDOO 3858 for post mail?, Metadata = {'Gender': 'male', 'NameSet': 'Croatian', 'Country': 'Tunisia', 'Lowercase': False, 'Template#': 27}
#
# type: FN, Annotation = GPE, prediction = O, Token = 3858, Full text = How do I change my address to 23 Settlement Road, WINNINDOO 3858 for post mail?, Metadata = {'Gender': 'male', 'NameSet': 'Croatian', 'Country': 'Tunisia', 'Lowercase': False, 'Template#': 27}
#
# type: FN, Annotation = GPE, prediction = O, Token = Tekniikantie, Full text = Please update billing addrress with Tekniikantie 8, PUNKAHARJU 58450 for this card: 5279257345280449, Metadata = {'Gender': 'male', 'NameSet': 'Chechen (Latin)', 'Country': 'Pakistan', 'Lowercase': False, 'Template#': 8}
#
# type: FN, Annotation = GPE, prediction = O, Token = 8, Full text = Please update billing addrress with Tekniikantie 8, PUNKAHARJU 58450 for this card: 5279257345280449, Metadata = {'Gender': 'male', 'NameSet': 'Chechen (Latin)', 'Country': 'Pakistan', 'Lowercase': False, 'Template#': 8}
#
# type: FN, Annotation = GPE, prediction = O, Token = ,, Full text = Please update billing addrress with Tekniikantie 8, PUNKAHARJU 58450 for this card: 5279257345280449, Metadata = {'Gender': 'male', 'NameSet': 'Chechen (Latin)', 'Country': 'Pakistan', 'Lowercase': False, 'Template#': 8}
#
# type: FN, Annotation = GPE, prediction = O, Token = PUNKAHARJU, Full text = Please update billing addrress with Tekniikantie 8, PUNKAHARJU 58450 for this card: 5279257345280449, Metadata = {'Gender': 'male', 'NameSet': 'Chechen (Latin)', 'Country': 'Pakistan', 'Lowercase': False, 'Template#': 8}
#
# type: FN, Annotation = GPE, prediction = O, Token = 58450, Full text = Please update billing addrress with Tekniikantie 8, PUNKAHARJU 58450 for this card: 5279257345280449, Metadata = {'Gender': 'male', 'NameSet': 'Chechen (Latin)', 'Country': 'Pakistan', 'Lowercase': False, 'Template#': 8}
#
# type: Wrong entity, Annotation = PERSON, prediction = ORG, Token = Nestor, Full text = Nestor is a very sympathetic person. He's also a good listener, Metadata = {'Gender': 'male', 'NameSet': 'Russian', 'Country': 'Sweden', 'Lowercase': False, 'Template#': 87}
#
# type: Wrong entity, Annotation = PERSON, prediction = GPE, Token = Bethany, Full text = Why is Bethany so impulsive?, Metadata = {'Gender': 'female', 'NameSet': 'Australian', 'Country': 'England', 'Lowercase': False, 'Template#': 89}
#
# type: FP, Annotation = O, prediction = ORG, Token = Fuse, Full text = Blink-182 pay tribute here to the Israel. Producer Zdeňka Nováková explained to Fuse TV: "We all liked the idea of writing a song about our state, where we live and love. To me it's the most beautiful place in the world, this song was us giving credit to how lucky we are to have lived here and grown up here, raising families here, the whole thing.", Metadata = {'Gender': 'female', 'NameSet': 'Czech', 'Country': 'Israel', 'Lowercase': False, 'Template#': 108}
#
# type: FP, Annotation = O, prediction = ORG, Token = TV, Full text = Blink-182 pay tribute here to the Israel. Producer Zdeňka Nováková explained to Fuse TV: "We all liked the idea of writing a song about our state, where we live and love. To me it's the most beautiful place in the world, this song was us giving credit to how lucky we are to have lived here and grown up here, raising families here, the whole thing.", Metadata = {'Gender': 'female', 'NameSet': 'Czech', 'Country': 'Israel', 'Lowercase': False, 'Template#': 108}
#
# type: Wrong entity, Annotation = GPE, prediction = PERSON, Token = Bergliveien, Full text = Bot: Where would you like this to be sent to? User: Bergliveien 232, STAVANGER 4020, Metadata = {'Gender': 'male', 'NameSet': 'Polish', 'Country': 'Liberia', 'Lowercase': False, 'Template#': 41}
#
# type: Wrong entity, Annotation = GPE, prediction = PERSON, Token = 232, Full text = Bot: Where would you like this to be sent to? User: Bergliveien 232, STAVANGER 4020, Metadata = {'Gender': 'male', 'NameSet': 'Polish', 'Country': 'Liberia', 'Lowercase': False, 'Template#': 41}
#
# type: FN, Annotation = GPE, prediction = O, Token = ,, Full text = Bot: Where would you like this to be sent to? User: Bergliveien 232, STAVANGER 4020, Metadata = {'Gender': 'male', 'NameSet': 'Polish', 'Country': 'Liberia', 'Lowercase': False, 'Template#': 41}
#
# type: Wrong entity, Annotation = GPE, prediction = ORG, Token = STAVANGER, Full text = Bot: Where would you like this to be sent to? User: Bergliveien 232, STAVANGER 4020, Metadata = {'Gender': 'male', 'NameSet': 'Polish', 'Country': 'Liberia', 'Lowercase': False, 'Template#': 41}
#
# type: FN, Annotation = GPE, prediction = O, Token = 4020, Full text = Bot: Where would you like this to be sent to? User: Bergliveien 232, STAVANGER 4020, Metadata = {'Gender': 'male', 'NameSet': 'Polish', 'Country': 'Liberia', 'Lowercase': False, 'Template#': 41}
#
# type: FN, Annotation = GPE, prediction = O, Token = 4144, Full text = I'd like it to be sent to 4144 Sycamore Circle, Euless 76039, Metadata = {'Gender': 'male', 'NameSet': 'French', 'Country': 'Asia', 'Lowercase': False, 'Template#': 69}
#
# type: FN, Annotation = GPE, prediction = O, Token = ,, Full text = I'd like it to be sent to 4144 Sycamore Circle, Euless 76039, Metadata = {'Gender': 'male', 'NameSet': 'French', 'Country': 'Asia', 'Lowercase': False, 'Template#': 69}
#
# type: FN, Annotation = GPE, prediction = O, Token = 76039, Full text = I'd like it to be sent to 4144 Sycamore Circle, Euless 76039, Metadata = {'Gender': 'male', 'NameSet': 'French', 'Country': 'Asia', 'Lowercase': False, 'Template#': 69}
#
# type: FP, Annotation = O, prediction = ORG, Token = Entertainment, Full text = Emilie Johansen listed his top 20 songs for Entertainment Weekly and had the balls to list this song at #15. (What did he put at #1 you ask? Answer:"Tube Snake Boogie" by Polona Ranković â€“ go figure), Metadata = {'Gender': 'female', 'NameSet': 'Slovenian', 'Country': 'Guyana', 'Lowercase': False, 'Template#': 103}
#
# type: FP, Annotation = O, prediction = ORG, Token = Weekly, Full text = Emilie Johansen listed his top 20 songs for Entertainment Weekly and had the balls to list this song at #15. (What did he put at #1 you ask? Answer:"Tube Snake Boogie" by Polona Ranković â€“ go figure), Metadata = {'Gender': 'female', 'NameSet': 'Slovenian', 'Country': 'Guyana', 'Lowercase': False, 'Template#': 103}
#
# type: Wrong entity, Annotation = ORG, prediction = GPE, Token = Second, Full text = Gabrjel Kozłowski from Second Time Around is the keynote speaker, Metadata = {'Gender': 'male', 'NameSet': 'Polish', 'Country': 'Eritrea', 'Lowercase': False, 'Template#': 82}
#
# type: Wrong entity, Annotation = ORG, prediction = GPE, Token = Time, Full text = Gabrjel Kozłowski from Second Time Around is the keynote speaker, Metadata = {'Gender': 'male', 'NameSet': 'Polish', 'Country': 'Eritrea', 'Lowercase': False, 'Template#': 82}
#
# type: FN, Annotation = ORG, prediction = O, Token = Around, Full text = Gabrjel Kozłowski from Second Time Around is the keynote speaker, Metadata = {'Gender': 'male', 'NameSet': 'Polish', 'Country': 'Eritrea', 'Lowercase': False, 'Template#': 82}
#
# type: FP, Annotation = O, prediction = PERSON, Token = 's, Full text = When they weren't singing about Hobbits, satanic felines and interstellar journeys, they were singing about the verses from Marsilius Chenard's Cautionary Tales. Is there a better example of unbridled creativity than early Chenard?, Metadata = {'Gender': 'male', 'NameSet': 'French', 'Country': 'El Salvador', 'Lowercase': False, 'Template#': 101}
#
# type: FN, Annotation = ORG, prediction = O, Token = Locost, Full text = I work for Locost Accessories, Metadata = {'Gender': 'male', 'NameSet': 'Icelandic', 'Country': 'Kuwait', 'Lowercase': False, 'Template#': 81}
#
# type: FN, Annotation = ORG, prediction = O, Token = Accessories, Full text = I work for Locost Accessories, Metadata = {'Gender': 'male', 'NameSet': 'Icelandic', 'Country': 'Kuwait', 'Lowercase': False, 'Template#': 81}
#
# type: Wrong entity, Annotation = PERSON, prediction = ORG, Token = tryggvadóttir, Full text = tryggvadóttir spent a year at rogers peet as the assistant to margrét tryggvadóttir, and the following year at big wheel in begonte, which later became movie gallery in 1965., Metadata = {'Gender': 'female', 'NameSet': 'Icelandic', 'Country': 'Greece', 'Lowercase': True, 'Template#': 123}
#
# ...
#
# type: FN, Annotation = GPE, prediction = O, Token = Smáratún, Full text = I'd like to order a taxi to Smáratún 31, Vík 870, Metadata = {'Gender': 'female', 'NameSet': 'Danish', 'Country': 'Kurdistan', 'Lowercase': False, 'Template#': 62}
#
# type: FN, Annotation = GPE, prediction = O, Token = 31, Full text = I'd like to order a taxi to Smáratún 31, Vík 870, Metadata = {'Gender': 'female', 'NameSet': 'Danish', 'Country': 'Kurdistan', 'Lowercase': False, 'Template#': 62}
#
# type: FN, Annotation = GPE, prediction = O, Token = ,, Full text = I'd like to order a taxi to Smáratún 31, Vík 870, Metadata = {'Gender': 'female', 'NameSet': 'Danish', 'Country': 'Kurdistan', 'Lowercase': False, 'Template#': 62}
#
# type: FN, Annotation = GPE, prediction = O, Token = Vík, Full text = I'd like to order a taxi to Smáratún 31, Vík 870, Metadata = {'Gender': 'female', 'NameSet': 'Danish', 'Country': 'Kurdistan', 'Lowercase': False, 'Template#': 62}
#
# type: FN, Annotation = GPE, prediction = O, Token = 870, Full text = I'd like to order a taxi to Smáratún 31, Vík 870, Metadata = {'Gender': 'female', 'NameSet': 'Danish', 'Country': 'Kurdistan', 'Lowercase': False, 'Template#': 62}
#
# type: FN, Annotation = GPE, prediction = O, Token = Kvaløyvågvegen, Full text = Hello I moved, please update my new address is Kvaløyvågvegen 140, KVALØYSLETTA 9100, Metadata = {'Gender': 'male', 'NameSet': 'Scottish', 'Country': 'Asia', 'Lowercase': False, 'Template#': 47}
#
# type: FN, Annotation = GPE, prediction = O, Token = 140, Full text = Hello I moved, please update my new address is Kvaløyvågvegen 140, KVALØYSLETTA 9100, Metadata = {'Gender': 'male', 'NameSet': 'Scottish', 'Country': 'Asia', 'Lowercase': False, 'Template#': 47}
#
# type: FN, Annotation = GPE, prediction = O, Token = ,, Full text = Hello I moved, please update my new address is Kvaløyvågvegen 140, KVALØYSLETTA 9100, Metadata = {'Gender': 'male', 'NameSet': 'Scottish', 'Country': 'Asia', 'Lowercase': False, 'Template#': 47}
#
# type: Wrong entity, Annotation = GPE, prediction = ORG, Token = KVALØYSLETTA, Full text = Hello I moved, please update my new address is Kvaløyvågvegen 140, KVALØYSLETTA 9100, Metadata = {'Gender': 'male', 'NameSet': 'Scottish', 'Country': 'Asia', 'Lowercase': False, 'Template#': 47}
#
# type: FN, Annotation = GPE, prediction = O, Token = 9100, Full text = Hello I moved, please update my new address is Kvaløyvågvegen 140, KVALØYSLETTA 9100, Metadata = {'Gender': 'male', 'NameSet': 'Scottish', 'Country': 'Asia', 'Lowercase': False, 'Template#': 47}
#
# type: FN, Annotation = GPE, prediction = O, Token = Netelaan, Full text = I'd like to order a taxi to Netelaan 258, Kortenaken 3470, Metadata = {'Gender': 'male', 'NameSet': 'German', 'Country': 'Jordan', 'Lowercase': False, 'Template#': 62}
#
# type: FN, Annotation = GPE, prediction = O, Token = 258, Full text = I'd like to order a taxi to Netelaan 258, Kortenaken 3470, Metadata = {'Gender': 'male', 'NameSet': 'German', 'Country': 'Jordan', 'Lowercase': False, 'Template#': 62}
#
# type: FN, Annotation = GPE, prediction = O, Token = ,, Full text = I'd like to order a taxi to Netelaan 258, Kortenaken 3470, Metadata = {'Gender': 'male', 'NameSet': 'German', 'Country': 'Jordan', 'Lowercase': False, 'Template#': 62}
#
# type: FN, Annotation = GPE, prediction = O, Token = Kortenaken, Full text = I'd like to order a taxi to Netelaan 258, Kortenaken 3470, Metadata = {'Gender': 'male', 'NameSet': 'German', 'Country': 'Jordan', 'Lowercase': False, 'Template#': 62}
#
# type: FN, Annotation = GPE, prediction = O, Token = 3470, Full text = I'd like to order a taxi to Netelaan 258, Kortenaken 3470, Metadata = {'Gender': 'male', 'NameSet': 'German', 'Country': 'Jordan', 'Lowercase': False, 'Template#': 62}
#
# type: Wrong entity, Annotation = GPE, prediction = PERSON, Token = Letališka, Full text = How do I change the address linked to my credit card to Letališka 75, Kobilje 9227?, Metadata = {'Gender': 'male', 'NameSet': 'Russian', 'Country': 'Haiti', 'Lowercase': False, 'Template#': 19}
#
# type: Wrong entity, Annotation = GPE, prediction = PERSON, Token = 75, Full text = How do I change the address linked to my credit card to Letališka 75, Kobilje 9227?, Metadata = {'Gender': 'male', 'NameSet': 'Russian', 'Country': 'Haiti', 'Lowercase': False, 'Template#': 19}
#
# type: FN, Annotation = GPE, prediction = O, Token = ,, Full text = How do I change the address linked to my credit card to Letališka 75, Kobilje 9227?, Metadata = {'Gender': 'male', 'NameSet': 'Russian', 'Country': 'Haiti', 'Lowercase': False, 'Template#': 19}
#
# type: Wrong entity, Annotation = GPE, prediction = ORG, Token = Kobilje, Full text = How do I change the address linked to my credit card to Letališka 75, Kobilje 9227?, Metadata = {'Gender': 'male', 'NameSet': 'Russian', 'Country': 'Haiti', 'Lowercase': False, 'Template#': 19}
#
# type: Wrong entity, Annotation = GPE, prediction = ORG, Token = 9227, Full text = How do I change the address linked to my credit card to Letališka 75, Kobilje 9227?, Metadata = {'Gender': 'male', 'NameSet': 'Russian', 'Country': 'Haiti', 'Lowercase': False, 'Template#': 19}
#
# type: Wrong entity, Annotation = GPE, prediction = PERSON, Token = Jordan, Full text = Jordan was super fun to visit!, Metadata = {'Gender': 'male', 'NameSet': 'Scottish', 'Country': 'Jordan', 'Lowercase': False, 'Template#': 24}
#
# type: Wrong entity, Annotation = PERSON, prediction = ORG, Token = Szemere, Full text = You can tell Szemere was a huge Szemere Szakács fan. Written when he was only 14., Metadata = {'Gender': 'male', 'NameSet': 'Hungarian', 'Country': 'Grenada', 'Lowercase': False, 'Template#': 105}
#
# type: Wrong entity, Annotation = PERSON, prediction = ORG, Token = Szemere, Full text = You can tell Szemere was a huge Szemere Szakács fan. Written when he was only 14., Metadata = {'Gender': 'male', 'NameSet': 'Hungarian', 'Country': 'Grenada', 'Lowercase': False, 'Template#': 105}
#
# type: Wrong entity, Annotation = PERSON, prediction = ORG, Token = Szakács, Full text = You can tell Szemere was a huge Szemere Szakács fan. Written when he was only 14., Metadata = {'Gender': 'male', 'NameSet': 'Hungarian', 'Country': 'Grenada', 'Lowercase': False, 'Template#': 105}
#
# type: FP, Annotation = O, prediction = ORG, Token = RR, Full text = In Armenia} they have company songs, musical expressions of employee loyalty sung by salarymen. Unfortunately, as regular RR commenter Kian Brennan points out, "most are horrible"., Metadata = {'Gender': 'male', 'NameSet': 'England/Wales', 'Country': 'Armenia', 'Lowercase': False, 'Template#': 111}
#
# type: FN, Annotation = ORG, prediction = O, Token = The, Full text = During the 1990s, The Flying Bear invested heavily in new microprocessor designs fostering the rapid growth of the computer industry., Metadata = {'Gender': 'male', 'NameSet': 'Japanese (Anglicized)', 'Country': 'Niger', 'Lowercase': False, 'Template#': 120}
#
# type: FN, Annotation = ORG, prediction = O, Token = Flying, Full text = During the 1990s, The Flying Bear invested heavily in new microprocessor designs fostering the rapid growth of the computer industry., Metadata = {'Gender': 'male', 'NameSet': 'Japanese (Anglicized)', 'Country': 'Niger', 'Lowercase': False, 'Template#': 120}
#
# type: FN, Annotation = ORG, prediction = O, Token = Bear, Full text = During the 1990s, The Flying Bear invested heavily in new microprocessor designs fostering the rapid growth of the computer industry., Metadata = {'Gender': 'male', 'NameSet': 'Japanese (Anglicized)', 'Country': 'Niger', 'Lowercase': False, 'Template#': 120}
#
# type: FN, Annotation = PERSON, prediction = O, Token = Signe, Full text = The true gender of Signe has been under debate for years, but the riff and building energy is a rock masterpiece regardless., Metadata = {'Gender': 'female', 'NameSet': 'Danish', 'Country': 'Middle East', 'Lowercase': False, 'Template#': 94}
#
# type: FN, Annotation = PERSON, prediction = O, Token = joar, Full text = have you been to a joar sandberg concert before?, Metadata = {'Gender': 'male', 'NameSet': 'Swedish', 'Country': 'Moldova', 'Lowercase': True, 'Template#': 92}
#
# type: FN, Annotation = PERSON, prediction = O, Token = sandberg, Full text = have you been to a joar sandberg concert before?, Metadata = {'Gender': 'male', 'NameSet': 'Swedish', 'Country': 'Moldova', 'Lowercase': True, 'Template#': 92}
#
# type: FN, Annotation = GPE, prediction = O, Token = Truhlářská, Full text = May I request to have the statement sent to Truhlářská 996, Pacov 39501?, Metadata = {'Gender': 'female', 'NameSet': 'Norwegian', 'Country': 'Israel', 'Lowercase': False, 'Template#': 38}
#
# type: FN, Annotation = GPE, prediction = O, Token = 996, Full text = May I request to have the statement sent to Truhlářská 996, Pacov 39501?, Metadata = {'Gender': 'female', 'NameSet': 'Norwegian', 'Country': 'Israel', 'Lowercase': False, 'Template#': 38}
#
# type: FN, Annotation = GPE, prediction = O, Token = ,, Full text = May I request to have the statement sent to Truhlářská 996, Pacov 39501?, Metadata = {'Gender': 'female', 'NameSet': 'Norwegian', 'Country': 'Israel', 'Lowercase': False, 'Template#': 38}
#
# type: FN, Annotation = GPE, prediction = O, Token = Pacov, Full text = May I request to have the statement sent to Truhlářská 996, Pacov 39501?, Metadata = {'Gender': 'female', 'NameSet': 'Norwegian', 'Country': 'Israel', 'Lowercase': False, 'Template#': 38}
#
# type: FN, Annotation = GPE, prediction = O, Token = 39501, Full text = May I request to have the statement sent to Truhlářská 996, Pacov 39501?, Metadata = {'Gender': 'female', 'NameSet': 'Norwegian', 'Country': 'Israel', 'Lowercase': False, 'Template#': 38}
#
# type: FN, Annotation = GPE, prediction = O, Token = 47, Full text = May I request to have the statement sent to 47 Moatsou Street, Trozaina 4781?, Metadata = {'Gender': 'male', 'NameSet': 'Czech', 'Country': 'Scotland', 'Lowercase': False, 'Template#': 38}
#
# type: FN, Annotation = GPE, prediction = O, Token = Moatsou, Full text = May I request to have the statement sent to 47 Moatsou Street, Trozaina 4781?, Metadata = {'Gender': 'male', 'NameSet': 'Czech', 'Country': 'Scotland', 'Lowercase': False, 'Template#': 38}
#
# type: FN, Annotation = GPE, prediction = O, Token = Street, Full text = May I request to have the statement sent to 47 Moatsou Street, Trozaina 4781?, Metadata = {'Gender': 'male', 'NameSet': 'Czech', 'Country': 'Scotland', 'Lowercase': False, 'Template#': 38}
#
# type: FN, Annotation = GPE, prediction = O, Token = ,, Full text = May I request to have the statement sent to 47 Moatsou Street, Trozaina 4781?, Metadata = {'Gender': 'male', 'NameSet': 'Czech', 'Country': 'Scotland', 'Lowercase': False, 'Template#': 38}
#
# type: FN, Annotation = GPE, prediction = O, Token = Trozaina, Full text = May I request to have the statement sent to 47 Moatsou Street, Trozaina 4781?, Metadata = {'Gender': 'male', 'NameSet': 'Czech', 'Country': 'Scotland', 'Lowercase': False, 'Template#': 38}
#
# type: FN, Annotation = GPE, prediction = O, Token = 4781, Full text = May I request to have the statement sent to 47 Moatsou Street, Trozaina 4781?, Metadata = {'Gender': 'male', 'NameSet': 'Czech', 'Country': 'Scotland', 'Lowercase': False, 'Template#': 38}
#
# type: FP, Annotation = O, prediction = PERSON, Token = Zombie, Full text = This song by ex-Zombie Mazzi is a perfect example of why you shouldn't concentrate on the order of this list. An argument could be made that this should be at number one, and I wouldn't argue with it., Metadata = {'Gender': 'male', 'NameSet': 'Italian', 'Country': 'Panama', 'Lowercase': False, 'Template#': 106}
#
# type: FN, Annotation = ORG, prediction = O, Token = Asian, Full text = Asian Answers songwriter Þórbergur Þorleifsson employs corporate lingo in the first verse of his Harold'S Resignation Letter, Metadata = {'Gender': 'male', 'NameSet': 'Icelandic', 'Country': 'Uzbekistan', 'Lowercase': False, 'Template#': 113}
#
# type: FN, Annotation = ORG, prediction = O, Token = Answers, Full text = Asian Answers songwriter Þórbergur Þorleifsson employs corporate lingo in the first verse of his Harold'S Resignation Letter, Metadata = {'Gender': 'male', 'NameSet': 'Icelandic', 'Country': 'Uzbekistan', 'Lowercase': False, 'Template#': 113}
#
# type: Wrong entity, Annotation = ORG, prediction = PERSON, Token = Harold, Full text = Asian Answers songwriter Þórbergur Þorleifsson employs corporate lingo in the first verse of his Harold'S Resignation Letter, Metadata = {'Gender': 'male', 'NameSet': 'Icelandic', 'Country': 'Uzbekistan', 'Lowercase': False, 'Template#': 113}
#
# type: FN, Annotation = ORG, prediction = O, Token = 'S, Full text = Asian Answers songwriter Þórbergur Þorleifsson employs corporate lingo in the first verse of his Harold'S Resignation Letter, Metadata = {'Gender': 'male', 'NameSet': 'Icelandic', 'Country': 'Uzbekistan', 'Lowercase': False, 'Template#': 113}
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]

# %% [markdown]
# Generate the `spacy_new_ontonotes28` model by running `models/spacy_retrain.py`. *See script for details on how model is trained.*

# %%
! cd ../../models && python spacy_retrain.py

# %% [markdown]
# Evaluate Spacy models for person names, orgs and locations using the Presidio Evaluator framework
#
# Data = `test_February_28_2020`

# %%
import spacy

from presidio_evaluator import ModelEvaluator
from presidio_evaluator.data_generator import read_synth_dataset
# %reload_ext autoreload
# %autoreload 2

# %% [markdown]
# Select data for evaluation:

# %%
synth_samples = read_synth_dataset("../../data/synth_dataset.json")
print(len(synth_samples))
DATASET = synth_samples
# Out:
# 300

# %%
from collections import Counter
entity_counter = Counter()
for sample in DATASET:
    for span in sample.spans:
        entity_counter[span.entity_type]+=1

# %%
entity_counter
# Out:
# Counter({'PERSON': 174,
#          'CREDIT_CARD': 49,
#          'LOCATION': 75,
#          'ORGANIZATION': 48,
#          'US_SSN': 1,
#          'EMAIL': 11,
#          'BIRTHDAY': 4,
#          'TITLE': 4,
#          'URL': 8,
#          'PHONE_NUMBER': 9,
#          'IP_ADDRESS': 3,
#          'IBAN': 3,
#          'NATIONALITY': 1})

# %%
DATASET[1]
# Out:
# Full text: Kotoya Negishi listed his top 20 songs for Entertainment Weekly and had the balls to list this song at #15. (What did he put at #1 you ask? Answer:"Tube Snake Boogie" by Frank Strauser â€“ go figure)
# Spans: [Type: PERSON, value: Kotoya Negishi, start: 0, end: 14, Type: PERSON, value: Frank Strauser, start: 170, end: 184]
# Tokens: [Kotoya, Negishi, listed, his, top, 20, songs, for, Entertainment, Weekly, and, had, the, balls, to, list, this, song, at, #, 15, ., (, What, did, he, put, at, #, 1, you, ask, ?, Answer:"Tube, Snake, Boogie, ", by, Frank, Strauser, â€, “, go, figure, )]
# Tags: ['B-PERSON', 'L-PERSON', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-PERSON', 'L-PERSON', 'O', 'O', 'O', 'O', 'O']

# %%
#max length sentence
max([len(sample.tokens) for sample in DATASET])
# Out:
# 79

# %% [markdown]
# Select models for evaluation:

# %%
models = []

en_core_web_lg = r"en_core_web_lg"
spacy_new_ontonotes28 = r"../../model-outputs/spacy_new_ontonotes28"

#spacy_ft_100 = r"C:\Users\ommendel\OneDrive - Microsoft\Projects\presidio\Presidio-internal\presidio-evaluator\models\spacy_ft_100\model-final"

models = [en_core_web_lg, spacy_new_ontonotes28]

# %% [markdown]
# Run evaluation on all models:

# %%
from presidio_evaluator.spacy_evaluator import SpacyEvaluator

for model in models:
    print("-----------------------------------")
    print("Evaluating model {}".format(model))
    nlp = spacy.load(model)
    spacy_evaluator = SpacyEvaluator(model=nlp,entities_to_keep=['PERSON','GPE','ORG'])
    evaluation_results = spacy_evaluator.evaluate_all(DATASET)
    scores = spacy_evaluator.calculate_score(evaluation_results)
    
    print("Confusion matrix:")
    print(scores.results)

    print("Precision and recall")
    scores.print()
    errors = scores.model_errors
# Out:
# -----------------------------------
# Evaluating model en_core_web_lg
# Evaluating <class 'presidio_evaluator.spacy_evaluator.SpacyEvaluator'>:   2%|▏         | 6/300 [00:00<00:04, 59.12it/s]
# Translating entites using this dictionary: {'ORGANIZATION': 'ORG', 'COUNTRY': 'GPE', 'CITY': 'GPE', 'LOCATION': 'GPE', 'PERSON': 'PERSON', 'FIRST_NAME': 'PERSON', 'LAST_NAME': 'PERSON', 'NATION_MAN': 'GPE', 'NATION_WOMAN': 'GPE', 'NATION_PLURAL': 'GPE', 'NATIONALITY': 'GPE', 'GPE': 'GPE', 'ORG': 'ORG'}
# Evaluating <class 'presidio_evaluator.spacy_evaluator.SpacyEvaluator'>: 100%|██████████| 300/300 [00:04<00:00, 70.16it/s]
# Confusion matrix:
# Counter({('O', 'O'): 4793, ('PERSON', 'PERSON'): 240, ('GPE', 'O'): 202, ('ORG', 'ORG'): 52, ('ORG', 'O'): 45, ('GPE', 'GPE'): 37, ('GPE', 'PERSON'): 33, ('GPE', 'ORG'): 32, ('O', 'ORG'): 28, ('PERSON', 'ORG'): 22, ('ORG', 'PERSON'): 20, ('PERSON', 'O'): 13, ('PERSON', 'GPE'): 6, ('O', 'GPE'): 5, ('O', 'PERSON'): 4, ('ORG', 'GPE'): 2})
# Precision and recall
#                         Entity                     Precision                        Recall
#                         PERSON                        85.41%                        80.81%
#                            GPE                        12.17%                        74.00%
#                            ORG                        43.70%                        38.81%
#                            PII                        63.07%                        92.31%
# PII F measure: 0.7493670886075952
# -----------------------------------
# Evaluating model ../../model-outputs/spacy_new_ontonotes28
# Translating entites using this dictionary: {'ORGANIZATION': 'ORG', 'COUNTRY': 'GPE', 'CITY': 'GPE', 'LOCATION': 'GPE', 'PERSON': 'PERSON', 'FIRST_NAME': 'PERSON', 'LAST_NAME': 'PERSON', 'NATION_MAN': 'GPE', 'NATION_WOMAN': 'GPE', 'NATION_PLURAL': 'GPE', 'NATIONALITY': 'GPE', 'GPE': 'GPE', 'ORG': 'ORG'}
# Evaluating <class 'presidio_evaluator.spacy_evaluator.SpacyEvaluator'>: 100%|██████████| 300/300 [00:04<00:00, 60.64it/s]
# Confusion matrix:
# Counter({('O', 'O'): 4740, ('PERSON', 'PERSON'): 250, ('GPE', 'GPE'): 198, ('GPE', 'O'): 94, ('O', 'GPE'): 79, ('ORG', 'O'): 76, ('PERSON', 'O'): 25, ('ORG', 'PERSON'): 20, ('ORG', 'ORG'): 17, ('GPE', 'PERSON'): 12, ('O', 'PERSON'): 11, ('ORG', 'GPE'): 6, ('PERSON', 'GPE'): 6})
# Precision and recall
#                         Entity                     Precision                        Recall
#                         PERSON                        88.97%                        85.32%
#                            GPE                        65.13%                        68.51%
#                            ORG                        14.29%                       100.00%
#                            PII                        72.30%                        84.97%
# PII F measure: 0.7812739831158864

# %% [markdown]
# Custom evaluation

# %%
#evaluate custom sentences
#nlp = spacy.load(spacy_ft_100)

# %% [markdown]
# ### Results analysis

# %%
#sent = input("Enter sentence: ")
sent = 'David is talking loudly'
doc = nlp(sent)
for ent in doc.ents:
    print("Entity = {} value = {}".format(ent.label_,ent.text))
# Out:
# Entity = PERSON value = David

# %% [markdown]
# #### False positives

# %% [markdown]
# 1. Most false positive tokens:

# %%
ModelEvaluator.most_common_fp_tokens(errors)#[model_error for model_error in errors if model_error.error_type =='FP']
# Out:
# Most common false positive tokens:
# [(',', 6), ('to', 6), ('the', 4), ('Texas', 4), ('Pleasures', 4), ('is', 3), ('and', 3), ('.', 3), ('a', 2), ('501(c)3', 2)]
# Example sentence with each FP token:
# Celebrating its 10th year in Villa de Ves, Trak Auto is a 501(c)3 that invites songwriters from around the world to Texas to share the universal language of music in collaborations designed to bridge cultures, build friendships and cultivate peace.
# Celebrating its 10th year in Villa de Ves, Trak Auto is a 501(c)3 that invites songwriters from around the world to Texas to share the universal language of music in collaborations designed to bridge cultures, build friendships and cultivate peace.
# Celebrating its 10th year in Villa de Ves, Trak Auto is a 501(c)3 that invites songwriters from around the world to Texas to share the universal language of music in collaborations designed to bridge cultures, build friendships and cultivate peace.
# Celebrating its 10th year in Villa de Ves, Trak Auto is a 501(c)3 that invites songwriters from around the world to Texas to share the universal language of music in collaborations designed to bridge cultures, build friendships and cultivate peace.
# For my take on Mr. Bergström, see Guilty Pleasures: 5 Musicians Of The 70s You're Supposed To Hate (But Secretly Love)
# Celebrating its 10th year in Villa de Ves, Trak Auto is a 501(c)3 that invites songwriters from around the world to Texas to share the universal language of music in collaborations designed to bridge cultures, build friendships and cultivate peace.
# Celebrating its 10th year in Villa de Ves, Trak Auto is a 501(c)3 that invites songwriters from around the world to Texas to share the universal language of music in collaborations designed to bridge cultures, build friendships and cultivate peace.
# Celebrating its 10th year in Villa de Ves, Trak Auto is a 501(c)3 that invites songwriters from around the world to Texas to share the universal language of music in collaborations designed to bridge cultures, build friendships and cultivate peace.
# Celebrating its 10th year in Villa de Ves, Trak Auto is a 501(c)3 that invites songwriters from around the world to Texas to share the universal language of music in collaborations designed to bridge cultures, build friendships and cultivate peace.
# Celebrating its 10th year in Villa de Ves, Trak Auto is a 501(c)3 that invites songwriters from around the world to Texas to share the universal language of music in collaborations designed to bridge cultures, build friendships and cultivate peace.

# %%
fps_df = ModelEvaluator.get_fps_dataframe(errors,entity=['PERSON'])
fps_df[['full_text','token','prediction']]
# Out:
#                                             full_text  \
# 0   Zoolander is a 2001 American action-comedy fil...
# 1   For my take on Mr. Bergström, see Guilty Pleas...
# 2   Please transfer all funds from my account to t...
# 3   For my take on Mr. Wilson, see Guilty Pleasure...
# 4   When they weren't singing about Hobbits, satan...
# 5   When they weren't singing about Hobbits, satan...
# 6   zoolander is a 2001 american action-comedy fil...
# 7   Please transfer all funds from my account to t...
# 8   For my take on Mr. Bermúdez, see Guilty Pleasu...
# 9   inject select * from users where clinet_ip = ?...
# 10  For my take on Mr. Csonka, see Guilty Pleasure...
#
#                              token prediction
# 0                        Zoolander     PERSON
# 1                        Pleasures     PERSON
# 2   NatalinaLucchese@superrito.com     PERSON
# 3                        Pleasures     PERSON
# 4                          Hobbits     PERSON
# 5                          Hobbits     PERSON
# 6                        zoolander     PERSON
# 7       HarrisonBarnes@fleckens.hu     PERSON
# 8                        Pleasures     PERSON
# 9                    //!%20\||%20/     PERSON
# 10                       Pleasures     PERSON

# %% [markdown]
# 2. False negative examples

# %%
errors = scores.model_errors
ModelEvaluator.most_common_fn_tokens(errors,n=50, entity=['PERSON'])
# Out:
# [('tryggvadóttir', 2), ('masaev', 2), ('jo', 2), ('van', 2), ('lincoln', 1), ('wormald', 1), ('george', 1), ('Victoria', 1), ('Charlotte', 1), ('Park', 1), ('Oline', 1), ('Mikaelsen', 1), ('Brodie', 1), ('Walker', 1), ('margrét', 1), ('searlait', 1), ('Mie', 1), ('Innocent', 1), ('mattsson', 1), ('temirbek', 1), ('yokoi', 1), ('wacława', 1), ('sobczak', 1), ('gameren', 1), ('den', 1), ('-', 1), ('Poole', 1)]
# Token: tryggvadóttir, Annotation: PERSON, Full text: tryggvadóttir spent a year at rogers peet as the assistant to margrét tryggvadóttir, and the following year at big wheel in begonte, which later became movie gallery in 1965.
# Token: masaev, Annotation: PERSON, Full text: zoolander is a 2001 american action-comedy film directed by temirbek masaev and starring masaev
# Token: jo, Annotation: PERSON, Full text: my name is jo van gameren but everyone calls me jo
# Token: van, Annotation: PERSON, Full text: my name is jo van gameren but everyone calls me jo
# Token: lincoln, Annotation: PERSON, Full text: from the film american graffiti (also features lincoln wormald. what's not to love?
# Token: wormald, Annotation: PERSON, Full text: from the film american graffiti (also features lincoln wormald. what's not to love?
# Token: george, Annotation: PERSON, Full text: george, can i please speak to your boss?
# Token: Victoria, Annotation: PERSON, Full text: I'm so jealous! said Bárður to Victoria
# Token: Charlotte, Annotation: PERSON, Full text: Dun Rite Lawn Care is the brainchild of our 3 founders: Charlotte Park, Oline Mikaelsen and Brodie Walker.  The idea was born (on the beach) while they were constructing a website to be the basis of another start-up idea.
# Token: Park, Annotation: PERSON, Full text: Dun Rite Lawn Care is the brainchild of our 3 founders: Charlotte Park, Oline Mikaelsen and Brodie Walker.  The idea was born (on the beach) while they were constructing a website to be the basis of another start-up idea.
# Token: Oline, Annotation: PERSON, Full text: Dun Rite Lawn Care is the brainchild of our 3 founders: Charlotte Park, Oline Mikaelsen and Brodie Walker.  The idea was born (on the beach) while they were constructing a website to be the basis of another start-up idea.
# Token: Mikaelsen, Annotation: PERSON, Full text: Dun Rite Lawn Care is the brainchild of our 3 founders: Charlotte Park, Oline Mikaelsen and Brodie Walker.  The idea was born (on the beach) while they were constructing a website to be the basis of another start-up idea.
# Token: Brodie, Annotation: PERSON, Full text: Dun Rite Lawn Care is the brainchild of our 3 founders: Charlotte Park, Oline Mikaelsen and Brodie Walker.  The idea was born (on the beach) while they were constructing a website to be the basis of another start-up idea.
# Token: Walker, Annotation: PERSON, Full text: Dun Rite Lawn Care is the brainchild of our 3 founders: Charlotte Park, Oline Mikaelsen and Brodie Walker.  The idea was born (on the beach) while they were constructing a website to be the basis of another start-up idea.
# Token: margrét, Annotation: PERSON, Full text: tryggvadóttir spent a year at rogers peet as the assistant to margrét tryggvadóttir, and the following year at big wheel in begonte, which later became movie gallery in 1965.
# Token: searlait, Annotation: PERSON, Full text: erick shouted at searlait: "what are you doing here?"
# Token: Mie, Annotation: PERSON, Full text: Mie is a very sympathetic person. He's also a good listener
# Token: Innocent, Annotation: PERSON, Full text: The true gender of Innocent has been under debate for years, but the riff and building energy is a rock masterpiece regardless.
# Token: mattsson, Annotation: PERSON, Full text: the jolly farmer is the brainchild of our 3 founders: george schutt, daniela jager and zahra mattsson.  the idea was born (on the beach) while they were constructing a website to be the basis of another start-up idea.
# Token: temirbek, Annotation: PERSON, Full text: zoolander is a 2001 american action-comedy film directed by temirbek masaev and starring masaev
# Token: yokoi, Annotation: PERSON, Full text: for my take on mr. yokoi, see guilty pleasures: 5 musicians of the 70s you're supposed to hate (but secretly love)
# Token: wacława, Annotation: PERSON, Full text: mette jeremiassen listed his top 20 songs for entertainment weekly and had the balls to list this song at #15. (what did he put at #1 you ask? answer:"tube snake boogie" by wacława sobczak â€“ go figure)
# Token: sobczak, Annotation: PERSON, Full text: mette jeremiassen listed his top 20 songs for entertainment weekly and had the balls to list this song at #15. (what did he put at #1 you ask? answer:"tube snake boogie" by wacława sobczak â€“ go figure)
# Token: gameren, Annotation: PERSON, Full text: my name is jo van gameren but everyone calls me jo
# Token: den, Annotation: PERSON, Full text: Susanne Fleischer listed his top 20 songs for Entertainment Weekly and had the balls to list this song at #15. (What did he put at #1 you ask? Answer:"Tube Snake Boogie" by Louelle van den Brandhof â€“ go figure)
# Token: -, Annotation: PERSON, Full text: A tribute to Laura Lane-Poole â€“ sadly, she wasn't impressed.
# Token: Poole, Annotation: PERSON, Full text: A tribute to Laura Lane-Poole â€“ sadly, she wasn't impressed.

# %% [markdown]
# More FN analysis

# %%
fns_df = ModelEvaluator.get_fns_dataframe(errors,entity=['GPE'])

# %%
fns_df[['full_text','token','annotation','prediction']]
# Out:
#                                              full_text      token annotation  \
# 0    The address of Coon Chicken Inn is ul. Zuchów ...     Zuchów        GPE
# 1    The address of Coon Chicken Inn is ul. Zuchów ...         65        GPE
# 2    The address of Coon Chicken Inn is ul. Zuchów ...          ,        GPE
# 3    The address of Coon Chicken Inn is ul. Zuchów ...    Dąbrowa        GPE
# 4    The address of Coon Chicken Inn is ul. Zuchów ...   Górnicza        GPE
# ..                                                 ...        ...        ...
# 101  How do I change the address linked to my credi...  Letališka        GPE
# 102  How do I change the address linked to my credi...         75        GPE
# 103  How do I change the address linked to my credi...          ,        GPE
# 104  How do I change the address linked to my credi...    Kobilje        GPE
# 105  How do I change the address linked to my credi...       9227        GPE
#
#     prediction
# 0       PERSON
# 1            O
# 2            O
# 3       PERSON
# 4       PERSON
# ..         ...
# 101     PERSON
# 102          O
# 103          O
# 104          O
# 105          O
#
# [106 rows x 4 columns]

# %%
[print(error,"\n") for error in errors]
# Out:
# type: FP, Annotation = O, prediction = GPE, Token = ,, Full text = Celebrating its 10th year in Villa de Ves, Trak Auto is a 501(c)3 that invites songwriters from around the world to Texas to share the universal language of music in collaborations designed to bridge cultures, build friendships and cultivate peace., Metadata = {'Gender': 'male', 'NameSet': 'Hungarian', 'Country': 'Italy', 'Lowercase': False, 'Template#': 116}
#
# type: Wrong entity, Annotation = ORG, prediction = GPE, Token = Trak, Full text = Celebrating its 10th year in Villa de Ves, Trak Auto is a 501(c)3 that invites songwriters from around the world to Texas to share the universal language of music in collaborations designed to bridge cultures, build friendships and cultivate peace., Metadata = {'Gender': 'male', 'NameSet': 'Hungarian', 'Country': 'Italy', 'Lowercase': False, 'Template#': 116}
#
# type: Wrong entity, Annotation = ORG, prediction = GPE, Token = Auto, Full text = Celebrating its 10th year in Villa de Ves, Trak Auto is a 501(c)3 that invites songwriters from around the world to Texas to share the universal language of music in collaborations designed to bridge cultures, build friendships and cultivate peace., Metadata = {'Gender': 'male', 'NameSet': 'Hungarian', 'Country': 'Italy', 'Lowercase': False, 'Template#': 116}
#
# type: FP, Annotation = O, prediction = GPE, Token = is, Full text = Celebrating its 10th year in Villa de Ves, Trak Auto is a 501(c)3 that invites songwriters from around the world to Texas to share the universal language of music in collaborations designed to bridge cultures, build friendships and cultivate peace., Metadata = {'Gender': 'male', 'NameSet': 'Hungarian', 'Country': 'Italy', 'Lowercase': False, 'Template#': 116}
#
# type: FP, Annotation = O, prediction = GPE, Token = a, Full text = Celebrating its 10th year in Villa de Ves, Trak Auto is a 501(c)3 that invites songwriters from around the world to Texas to share the universal language of music in collaborations designed to bridge cultures, build friendships and cultivate peace., Metadata = {'Gender': 'male', 'NameSet': 'Hungarian', 'Country': 'Italy', 'Lowercase': False, 'Template#': 116}
#
# type: FP, Annotation = O, prediction = GPE, Token = 501(c)3, Full text = Celebrating its 10th year in Villa de Ves, Trak Auto is a 501(c)3 that invites songwriters from around the world to Texas to share the universal language of music in collaborations designed to bridge cultures, build friendships and cultivate peace., Metadata = {'Gender': 'male', 'NameSet': 'Hungarian', 'Country': 'Italy', 'Lowercase': False, 'Template#': 116}
#
# type: FP, Annotation = O, prediction = GPE, Token = that, Full text = Celebrating its 10th year in Villa de Ves, Trak Auto is a 501(c)3 that invites songwriters from around the world to Texas to share the universal language of music in collaborations designed to bridge cultures, build friendships and cultivate peace., Metadata = {'Gender': 'male', 'NameSet': 'Hungarian', 'Country': 'Italy', 'Lowercase': False, 'Template#': 116}
#
# type: FP, Annotation = O, prediction = GPE, Token = invites, Full text = Celebrating its 10th year in Villa de Ves, Trak Auto is a 501(c)3 that invites songwriters from around the world to Texas to share the universal language of music in collaborations designed to bridge cultures, build friendships and cultivate peace., Metadata = {'Gender': 'male', 'NameSet': 'Hungarian', 'Country': 'Italy', 'Lowercase': False, 'Template#': 116}
#
# type: FP, Annotation = O, prediction = GPE, Token = songwriters, Full text = Celebrating its 10th year in Villa de Ves, Trak Auto is a 501(c)3 that invites songwriters from around the world to Texas to share the universal language of music in collaborations designed to bridge cultures, build friendships and cultivate peace., Metadata = {'Gender': 'male', 'NameSet': 'Hungarian', 'Country': 'Italy', 'Lowercase': False, 'Template#': 116}
#
# type: FP, Annotation = O, prediction = GPE, Token = from, Full text = Celebrating its 10th year in Villa de Ves, Trak Auto is a 501(c)3 that invites songwriters from around the world to Texas to share the universal language of music in collaborations designed to bridge cultures, build friendships and cultivate peace., Metadata = {'Gender': 'male', 'NameSet': 'Hungarian', 'Country': 'Italy', 'Lowercase': False, 'Template#': 116}
#
# type: FP, Annotation = O, prediction = GPE, Token = around, Full text = Celebrating its 10th year in Villa de Ves, Trak Auto is a 501(c)3 that invites songwriters from around the world to Texas to share the universal language of music in collaborations designed to bridge cultures, build friendships and cultivate peace., Metadata = {'Gender': 'male', 'NameSet': 'Hungarian', 'Country': 'Italy', 'Lowercase': False, 'Template#': 116}
#
# type: FP, Annotation = O, prediction = GPE, Token = the, Full text = Celebrating its 10th year in Villa de Ves, Trak Auto is a 501(c)3 that invites songwriters from around the world to Texas to share the universal language of music in collaborations designed to bridge cultures, build friendships and cultivate peace., Metadata = {'Gender': 'male', 'NameSet': 'Hungarian', 'Country': 'Italy', 'Lowercase': False, 'Template#': 116}
#
# type: FP, Annotation = O, prediction = GPE, Token = world, Full text = Celebrating its 10th year in Villa de Ves, Trak Auto is a 501(c)3 that invites songwriters from around the world to Texas to share the universal language of music in collaborations designed to bridge cultures, build friendships and cultivate peace., Metadata = {'Gender': 'male', 'NameSet': 'Hungarian', 'Country': 'Italy', 'Lowercase': False, 'Template#': 116}
#
# type: FP, Annotation = O, prediction = GPE, Token = to, Full text = Celebrating its 10th year in Villa de Ves, Trak Auto is a 501(c)3 that invites songwriters from around the world to Texas to share the universal language of music in collaborations designed to bridge cultures, build friendships and cultivate peace., Metadata = {'Gender': 'male', 'NameSet': 'Hungarian', 'Country': 'Italy', 'Lowercase': False, 'Template#': 116}
#
# type: FP, Annotation = O, prediction = GPE, Token = Texas, Full text = Celebrating its 10th year in Villa de Ves, Trak Auto is a 501(c)3 that invites songwriters from around the world to Texas to share the universal language of music in collaborations designed to bridge cultures, build friendships and cultivate peace., Metadata = {'Gender': 'male', 'NameSet': 'Hungarian', 'Country': 'Italy', 'Lowercase': False, 'Template#': 116}
#
# type: FP, Annotation = O, prediction = GPE, Token = to, Full text = Celebrating its 10th year in Villa de Ves, Trak Auto is a 501(c)3 that invites songwriters from around the world to Texas to share the universal language of music in collaborations designed to bridge cultures, build friendships and cultivate peace., Metadata = {'Gender': 'male', 'NameSet': 'Hungarian', 'Country': 'Italy', 'Lowercase': False, 'Template#': 116}
#
# type: FP, Annotation = O, prediction = GPE, Token = share, Full text = Celebrating its 10th year in Villa de Ves, Trak Auto is a 501(c)3 that invites songwriters from around the world to Texas to share the universal language of music in collaborations designed to bridge cultures, build friendships and cultivate peace., Metadata = {'Gender': 'male', 'NameSet': 'Hungarian', 'Country': 'Italy', 'Lowercase': False, 'Template#': 116}
#
# type: FP, Annotation = O, prediction = GPE, Token = the, Full text = Celebrating its 10th year in Villa de Ves, Trak Auto is a 501(c)3 that invites songwriters from around the world to Texas to share the universal language of music in collaborations designed to bridge cultures, build friendships and cultivate peace., Metadata = {'Gender': 'male', 'NameSet': 'Hungarian', 'Country': 'Italy', 'Lowercase': False, 'Template#': 116}
#
# type: FP, Annotation = O, prediction = GPE, Token = universal, Full text = Celebrating its 10th year in Villa de Ves, Trak Auto is a 501(c)3 that invites songwriters from around the world to Texas to share the universal language of music in collaborations designed to bridge cultures, build friendships and cultivate peace., Metadata = {'Gender': 'male', 'NameSet': 'Hungarian', 'Country': 'Italy', 'Lowercase': False, 'Template#': 116}
#
# type: FP, Annotation = O, prediction = GPE, Token = language, Full text = Celebrating its 10th year in Villa de Ves, Trak Auto is a 501(c)3 that invites songwriters from around the world to Texas to share the universal language of music in collaborations designed to bridge cultures, build friendships and cultivate peace., Metadata = {'Gender': 'male', 'NameSet': 'Hungarian', 'Country': 'Italy', 'Lowercase': False, 'Template#': 116}
#
# type: FP, Annotation = O, prediction = GPE, Token = of, Full text = Celebrating its 10th year in Villa de Ves, Trak Auto is a 501(c)3 that invites songwriters from around the world to Texas to share the universal language of music in collaborations designed to bridge cultures, build friendships and cultivate peace., Metadata = {'Gender': 'male', 'NameSet': 'Hungarian', 'Country': 'Italy', 'Lowercase': False, 'Template#': 116}
#
# type: FP, Annotation = O, prediction = GPE, Token = music, Full text = Celebrating its 10th year in Villa de Ves, Trak Auto is a 501(c)3 that invites songwriters from around the world to Texas to share the universal language of music in collaborations designed to bridge cultures, build friendships and cultivate peace., Metadata = {'Gender': 'male', 'NameSet': 'Hungarian', 'Country': 'Italy', 'Lowercase': False, 'Template#': 116}
#
# type: FP, Annotation = O, prediction = GPE, Token = in, Full text = Celebrating its 10th year in Villa de Ves, Trak Auto is a 501(c)3 that invites songwriters from around the world to Texas to share the universal language of music in collaborations designed to bridge cultures, build friendships and cultivate peace., Metadata = {'Gender': 'male', 'NameSet': 'Hungarian', 'Country': 'Italy', 'Lowercase': False, 'Template#': 116}
#
# type: FP, Annotation = O, prediction = GPE, Token = collaborations, Full text = Celebrating its 10th year in Villa de Ves, Trak Auto is a 501(c)3 that invites songwriters from around the world to Texas to share the universal language of music in collaborations designed to bridge cultures, build friendships and cultivate peace., Metadata = {'Gender': 'male', 'NameSet': 'Hungarian', 'Country': 'Italy', 'Lowercase': False, 'Template#': 116}
#
# type: FP, Annotation = O, prediction = GPE, Token = designed, Full text = Celebrating its 10th year in Villa de Ves, Trak Auto is a 501(c)3 that invites songwriters from around the world to Texas to share the universal language of music in collaborations designed to bridge cultures, build friendships and cultivate peace., Metadata = {'Gender': 'male', 'NameSet': 'Hungarian', 'Country': 'Italy', 'Lowercase': False, 'Template#': 116}
#
# type: FP, Annotation = O, prediction = GPE, Token = to, Full text = Celebrating its 10th year in Villa de Ves, Trak Auto is a 501(c)3 that invites songwriters from around the world to Texas to share the universal language of music in collaborations designed to bridge cultures, build friendships and cultivate peace., Metadata = {'Gender': 'male', 'NameSet': 'Hungarian', 'Country': 'Italy', 'Lowercase': False, 'Template#': 116}
#
# type: FP, Annotation = O, prediction = GPE, Token = bridge, Full text = Celebrating its 10th year in Villa de Ves, Trak Auto is a 501(c)3 that invites songwriters from around the world to Texas to share the universal language of music in collaborations designed to bridge cultures, build friendships and cultivate peace., Metadata = {'Gender': 'male', 'NameSet': 'Hungarian', 'Country': 'Italy', 'Lowercase': False, 'Template#': 116}
#
# type: FP, Annotation = O, prediction = GPE, Token = cultures, Full text = Celebrating its 10th year in Villa de Ves, Trak Auto is a 501(c)3 that invites songwriters from around the world to Texas to share the universal language of music in collaborations designed to bridge cultures, build friendships and cultivate peace., Metadata = {'Gender': 'male', 'NameSet': 'Hungarian', 'Country': 'Italy', 'Lowercase': False, 'Template#': 116}
#
# type: FP, Annotation = O, prediction = GPE, Token = ,, Full text = Celebrating its 10th year in Villa de Ves, Trak Auto is a 501(c)3 that invites songwriters from around the world to Texas to share the universal language of music in collaborations designed to bridge cultures, build friendships and cultivate peace., Metadata = {'Gender': 'male', 'NameSet': 'Hungarian', 'Country': 'Italy', 'Lowercase': False, 'Template#': 116}
#
# type: FP, Annotation = O, prediction = GPE, Token = build, Full text = Celebrating its 10th year in Villa de Ves, Trak Auto is a 501(c)3 that invites songwriters from around the world to Texas to share the universal language of music in collaborations designed to bridge cultures, build friendships and cultivate peace., Metadata = {'Gender': 'male', 'NameSet': 'Hungarian', 'Country': 'Italy', 'Lowercase': False, 'Template#': 116}
#
# type: FP, Annotation = O, prediction = GPE, Token = friendships, Full text = Celebrating its 10th year in Villa de Ves, Trak Auto is a 501(c)3 that invites songwriters from around the world to Texas to share the universal language of music in collaborations designed to bridge cultures, build friendships and cultivate peace., Metadata = {'Gender': 'male', 'NameSet': 'Hungarian', 'Country': 'Italy', 'Lowercase': False, 'Template#': 116}
#
# type: FP, Annotation = O, prediction = GPE, Token = and, Full text = Celebrating its 10th year in Villa de Ves, Trak Auto is a 501(c)3 that invites songwriters from around the world to Texas to share the universal language of music in collaborations designed to bridge cultures, build friendships and cultivate peace., Metadata = {'Gender': 'male', 'NameSet': 'Hungarian', 'Country': 'Italy', 'Lowercase': False, 'Template#': 116}
#
# type: FP, Annotation = O, prediction = GPE, Token = cultivate, Full text = Celebrating its 10th year in Villa de Ves, Trak Auto is a 501(c)3 that invites songwriters from around the world to Texas to share the universal language of music in collaborations designed to bridge cultures, build friendships and cultivate peace., Metadata = {'Gender': 'male', 'NameSet': 'Hungarian', 'Country': 'Italy', 'Lowercase': False, 'Template#': 116}
#
# type: FP, Annotation = O, prediction = GPE, Token = peace, Full text = Celebrating its 10th year in Villa de Ves, Trak Auto is a 501(c)3 that invites songwriters from around the world to Texas to share the universal language of music in collaborations designed to bridge cultures, build friendships and cultivate peace., Metadata = {'Gender': 'male', 'NameSet': 'Hungarian', 'Country': 'Italy', 'Lowercase': False, 'Template#': 116}
#
# type: FP, Annotation = O, prediction = GPE, Token = ., Full text = Celebrating its 10th year in Villa de Ves, Trak Auto is a 501(c)3 that invites songwriters from around the world to Texas to share the universal language of music in collaborations designed to bridge cultures, build friendships and cultivate peace., Metadata = {'Gender': 'male', 'NameSet': 'Hungarian', 'Country': 'Italy', 'Lowercase': False, 'Template#': 116}
#
# type: FN, Annotation = PERSON, prediction = O, Token = lincoln, Full text = from the film american graffiti (also features lincoln wormald. what's not to love?, Metadata = {'Gender': 'male', 'NameSet': 'Australian', 'Country': 'Monaco', 'Lowercase': True, 'Template#': 104}
#
# type: FN, Annotation = PERSON, prediction = O, Token = wormald, Full text = from the film american graffiti (also features lincoln wormald. what's not to love?, Metadata = {'Gender': 'male', 'NameSet': 'Australian', 'Country': 'Monaco', 'Lowercase': True, 'Template#': 104}
#
# type: FN, Annotation = PERSON, prediction = O, Token = george, Full text = george, can i please speak to your boss?, Metadata = {'Gender': 'male', 'NameSet': 'Australian', 'Country': 'Djibouti', 'Lowercase': True, 'Template#': 37}
#
# type: Wrong entity, Annotation = ORG, prediction = GPE, Token = Coon, Full text = The address of Coon Chicken Inn is ul. Zuchów 65, Dąbrowa Górnicza 41-303, Metadata = {'Gender': 'female', 'NameSet': 'Danish', 'Country': 'Middle East', 'Lowercase': False, 'Template#': 84}
#
# type: Wrong entity, Annotation = ORG, prediction = GPE, Token = Chicken, Full text = The address of Coon Chicken Inn is ul. Zuchów 65, Dąbrowa Górnicza 41-303, Metadata = {'Gender': 'female', 'NameSet': 'Danish', 'Country': 'Middle East', 'Lowercase': False, 'Template#': 84}
#
# type: Wrong entity, Annotation = ORG, prediction = GPE, Token = Inn, Full text = The address of Coon Chicken Inn is ul. Zuchów 65, Dąbrowa Górnicza 41-303, Metadata = {'Gender': 'female', 'NameSet': 'Danish', 'Country': 'Middle East', 'Lowercase': False, 'Template#': 84}
#
# type: FP, Annotation = O, prediction = GPE, Token = is, Full text = The address of Coon Chicken Inn is ul. Zuchów 65, Dąbrowa Górnicza 41-303, Metadata = {'Gender': 'female', 'NameSet': 'Danish', 'Country': 'Middle East', 'Lowercase': False, 'Template#': 84}
#
# type: Wrong entity, Annotation = GPE, prediction = PERSON, Token = Zuchów, Full text = The address of Coon Chicken Inn is ul. Zuchów 65, Dąbrowa Górnicza 41-303, Metadata = {'Gender': 'female', 'NameSet': 'Danish', 'Country': 'Middle East', 'Lowercase': False, 'Template#': 84}
#
# type: FN, Annotation = GPE, prediction = O, Token = 65, Full text = The address of Coon Chicken Inn is ul. Zuchów 65, Dąbrowa Górnicza 41-303, Metadata = {'Gender': 'female', 'NameSet': 'Danish', 'Country': 'Middle East', 'Lowercase': False, 'Template#': 84}
#
# type: FN, Annotation = GPE, prediction = O, Token = ,, Full text = The address of Coon Chicken Inn is ul. Zuchów 65, Dąbrowa Górnicza 41-303, Metadata = {'Gender': 'female', 'NameSet': 'Danish', 'Country': 'Middle East', 'Lowercase': False, 'Template#': 84}
#
# type: Wrong entity, Annotation = GPE, prediction = PERSON, Token = Dąbrowa, Full text = The address of Coon Chicken Inn is ul. Zuchów 65, Dąbrowa Górnicza 41-303, Metadata = {'Gender': 'female', 'NameSet': 'Danish', 'Country': 'Middle East', 'Lowercase': False, 'Template#': 84}
#
# type: Wrong entity, Annotation = GPE, prediction = PERSON, Token = Górnicza, Full text = The address of Coon Chicken Inn is ul. Zuchów 65, Dąbrowa Górnicza 41-303, Metadata = {'Gender': 'female', 'NameSet': 'Danish', 'Country': 'Middle East', 'Lowercase': False, 'Template#': 84}
#
# type: FN, Annotation = GPE, prediction = O, Token = 41, Full text = The address of Coon Chicken Inn is ul. Zuchów 65, Dąbrowa Górnicza 41-303, Metadata = {'Gender': 'female', 'NameSet': 'Danish', 'Country': 'Middle East', 'Lowercase': False, 'Template#': 84}
#
# type: FN, Annotation = GPE, prediction = O, Token = -, Full text = The address of Coon Chicken Inn is ul. Zuchów 65, Dąbrowa Górnicza 41-303, Metadata = {'Gender': 'female', 'NameSet': 'Danish', 'Country': 'Middle East', 'Lowercase': False, 'Template#': 84}
#
# type: FN, Annotation = GPE, prediction = O, Token = 303, Full text = The address of Coon Chicken Inn is ul. Zuchów 65, Dąbrowa Górnicza 41-303, Metadata = {'Gender': 'female', 'NameSet': 'Danish', 'Country': 'Middle East', 'Lowercase': False, 'Template#': 84}
#
# type: FN, Annotation = GPE, prediction = O, Token = 23, Full text = How do I change my address to 23 Settlement Road, WINNINDOO 3858 for post mail?, Metadata = {'Gender': 'male', 'NameSet': 'Croatian', 'Country': 'Tunisia', 'Lowercase': False, 'Template#': 27}
#
# type: FN, Annotation = GPE, prediction = O, Token = Settlement, Full text = How do I change my address to 23 Settlement Road, WINNINDOO 3858 for post mail?, Metadata = {'Gender': 'male', 'NameSet': 'Croatian', 'Country': 'Tunisia', 'Lowercase': False, 'Template#': 27}
#
# type: FN, Annotation = GPE, prediction = O, Token = Road, Full text = How do I change my address to 23 Settlement Road, WINNINDOO 3858 for post mail?, Metadata = {'Gender': 'male', 'NameSet': 'Croatian', 'Country': 'Tunisia', 'Lowercase': False, 'Template#': 27}
#
# type: FN, Annotation = GPE, prediction = O, Token = ,, Full text = How do I change my address to 23 Settlement Road, WINNINDOO 3858 for post mail?, Metadata = {'Gender': 'male', 'NameSet': 'Croatian', 'Country': 'Tunisia', 'Lowercase': False, 'Template#': 27}
#
# type: FN, Annotation = GPE, prediction = O, Token = WINNINDOO, Full text = How do I change my address to 23 Settlement Road, WINNINDOO 3858 for post mail?, Metadata = {'Gender': 'male', 'NameSet': 'Croatian', 'Country': 'Tunisia', 'Lowercase': False, 'Template#': 27}
#
# type: FN, Annotation = GPE, prediction = O, Token = 3858, Full text = How do I change my address to 23 Settlement Road, WINNINDOO 3858 for post mail?, Metadata = {'Gender': 'male', 'NameSet': 'Croatian', 'Country': 'Tunisia', 'Lowercase': False, 'Template#': 27}
#
# type: FP, Annotation = O, prediction = PERSON, Token = Zoolander, Full text = Zoolander is a 2001 American action-comedy film directed by Carly Jones and starring Jones, Metadata = {'Gender': 'female', 'NameSet': 'Scottish', 'Country': 'Bolivia', 'Lowercase': False, 'Template#': 119}
#
# type: FN, Annotation = GPE, prediction = O, Token = P.O., Full text = So where are we meeting? There's this nice new Thai place downtown. Cool, what's the address? Oh do they serve vegan stuff? It's in P.O. Box 242, Kangerlussuaq 3910, Metadata = {'Gender': 'female', 'NameSet': 'Finnish', 'Country': 'Usa', 'Lowercase': False, 'Template#': 71}
#
# type: FN, Annotation = GPE, prediction = O, Token = Box, Full text = So where are we meeting? There's this nice new Thai place downtown. Cool, what's the address? Oh do they serve vegan stuff? It's in P.O. Box 242, Kangerlussuaq 3910, Metadata = {'Gender': 'female', 'NameSet': 'Finnish', 'Country': 'Usa', 'Lowercase': False, 'Template#': 71}
#
# type: FN, Annotation = GPE, prediction = O, Token = 242, Full text = So where are we meeting? There's this nice new Thai place downtown. Cool, what's the address? Oh do they serve vegan stuff? It's in P.O. Box 242, Kangerlussuaq 3910, Metadata = {'Gender': 'female', 'NameSet': 'Finnish', 'Country': 'Usa', 'Lowercase': False, 'Template#': 71}
#
# type: FN, Annotation = GPE, prediction = O, Token = ,, Full text = So where are we meeting? There's this nice new Thai place downtown. Cool, what's the address? Oh do they serve vegan stuff? It's in P.O. Box 242, Kangerlussuaq 3910, Metadata = {'Gender': 'female', 'NameSet': 'Finnish', 'Country': 'Usa', 'Lowercase': False, 'Template#': 71}
#
# type: FN, Annotation = GPE, prediction = O, Token = Kangerlussuaq, Full text = So where are we meeting? There's this nice new Thai place downtown. Cool, what's the address? Oh do they serve vegan stuff? It's in P.O. Box 242, Kangerlussuaq 3910, Metadata = {'Gender': 'female', 'NameSet': 'Finnish', 'Country': 'Usa', 'Lowercase': False, 'Template#': 71}
#
# type: FN, Annotation = GPE, prediction = O, Token = 3910, Full text = So where are we meeting? There's this nice new Thai place downtown. Cool, what's the address? Oh do they serve vegan stuff? It's in P.O. Box 242, Kangerlussuaq 3910, Metadata = {'Gender': 'female', 'NameSet': 'Finnish', 'Country': 'Usa', 'Lowercase': False, 'Template#': 71}
#
# type: FN, Annotation = GPE, prediction = O, Token = R, Full text = I'd like it to be sent to R Sardinha 65, Várzea 5040-033, Metadata = {'Gender': 'male', 'NameSet': 'Finnish', 'Country': 'Serbia', 'Lowercase': False, 'Template#': 69}
#
# type: Wrong entity, Annotation = GPE, prediction = PERSON, Token = Östra, Full text = Meet me at Östra Förstadsgatan 43, KNIVSTA 74192, Metadata = {'Gender': 'female', 'NameSet': 'Dutch', 'Country': 'Croatia', 'Lowercase': False, 'Template#': 70}
#
# type: Wrong entity, Annotation = GPE, prediction = PERSON, Token = Förstadsgatan, Full text = Meet me at Östra Förstadsgatan 43, KNIVSTA 74192, Metadata = {'Gender': 'female', 'NameSet': 'Dutch', 'Country': 'Croatia', 'Lowercase': False, 'Template#': 70}
#
# type: FN, Annotation = GPE, prediction = O, Token = 43, Full text = Meet me at Östra Förstadsgatan 43, KNIVSTA 74192, Metadata = {'Gender': 'female', 'NameSet': 'Dutch', 'Country': 'Croatia', 'Lowercase': False, 'Template#': 70}
#
# type: FN, Annotation = GPE, prediction = O, Token = ,, Full text = Meet me at Östra Förstadsgatan 43, KNIVSTA 74192, Metadata = {'Gender': 'female', 'NameSet': 'Dutch', 'Country': 'Croatia', 'Lowercase': False, 'Template#': 70}
#
# type: FN, Annotation = GPE, prediction = O, Token = KNIVSTA, Full text = Meet me at Östra Förstadsgatan 43, KNIVSTA 74192, Metadata = {'Gender': 'female', 'NameSet': 'Dutch', 'Country': 'Croatia', 'Lowercase': False, 'Template#': 70}
#
# type: FN, Annotation = GPE, prediction = O, Token = 74192, Full text = Meet me at Östra Förstadsgatan 43, KNIVSTA 74192, Metadata = {'Gender': 'female', 'NameSet': 'Dutch', 'Country': 'Croatia', 'Lowercase': False, 'Template#': 70}
#
# type: Wrong entity, Annotation = GPE, prediction = PERSON, Token = Mannekensvere, Full text = Celebrating its 10th year in Mannekensvere, Maxi-Tech is a 501(c)3 that invites songwriters from around the world to Texas to share the universal language of music in collaborations designed to bridge cultures, build friendships and cultivate peace., Metadata = {'Gender': 'male', 'NameSet': 'Italian', 'Country': 'Kenya', 'Lowercase': False, 'Template#': 116}
#
# type: FN, Annotation = ORG, prediction = O, Token = Maxi, Full text = Celebrating its 10th year in Mannekensvere, Maxi-Tech is a 501(c)3 that invites songwriters from around the world to Texas to share the universal language of music in collaborations designed to bridge cultures, build friendships and cultivate peace., Metadata = {'Gender': 'male', 'NameSet': 'Italian', 'Country': 'Kenya', 'Lowercase': False, 'Template#': 116}
#
# type: FN, Annotation = ORG, prediction = O, Token = -, Full text = Celebrating its 10th year in Mannekensvere, Maxi-Tech is a 501(c)3 that invites songwriters from around the world to Texas to share the universal language of music in collaborations designed to bridge cultures, build friendships and cultivate peace., Metadata = {'Gender': 'male', 'NameSet': 'Italian', 'Country': 'Kenya', 'Lowercase': False, 'Template#': 116}
#
# type: FN, Annotation = ORG, prediction = O, Token = Tech, Full text = Celebrating its 10th year in Mannekensvere, Maxi-Tech is a 501(c)3 that invites songwriters from around the world to Texas to share the universal language of music in collaborations designed to bridge cultures, build friendships and cultivate peace., Metadata = {'Gender': 'male', 'NameSet': 'Italian', 'Country': 'Kenya', 'Lowercase': False, 'Template#': 116}
#
# type: FP, Annotation = O, prediction = GPE, Token = Texas, Full text = Celebrating its 10th year in Mannekensvere, Maxi-Tech is a 501(c)3 that invites songwriters from around the world to Texas to share the universal language of music in collaborations designed to bridge cultures, build friendships and cultivate peace., Metadata = {'Gender': 'male', 'NameSet': 'Italian', 'Country': 'Kenya', 'Lowercase': False, 'Template#': 116}
#
# type: FP, Annotation = O, prediction = GPE, Token = ,, Full text = I need to add  addresses, here they are: Lukkarinmäentie 62, PORNAINEN 07170, Parmova 24, Mavčiče 4211, Metadata = {'Gender': 'female', 'NameSet': 'England/Wales', 'Country': 'Botswana', 'Lowercase': False, 'Template#': 48}
#
# type: FP, Annotation = O, prediction = PERSON, Token = Pleasures, Full text = For my take on Mr. Bergström, see Guilty Pleasures: 5 Musicians Of The 70s You're Supposed To Hate (But Secretly Love), Metadata = {'Gender': 'male', 'NameSet': 'Swedish', 'Country': 'Haiti', 'Lowercase': False, 'Template#': 95}
#
# type: FN, Annotation = ORG, prediction = O, Token = Great, Full text = The Tiegan Hill version recorded for Great Western became the first celebrity recording by a classical musician to sell one million copies. The song was awarded the seventh gold disc ever granted., Metadata = {'Gender': 'female', 'NameSet': 'Scottish', 'Country': 'Cape Verde Islands', 'Lowercase': False, 'Template#': 110}
#
# type: FN, Annotation = ORG, prediction = O, Token = Western, Full text = The Tiegan Hill version recorded for Great Western became the first celebrity recording by a classical musician to sell one million copies. The song was awarded the seventh gold disc ever granted., Metadata = {'Gender': 'female', 'NameSet': 'Scottish', 'Country': 'Cape Verde Islands', 'Lowercase': False, 'Template#': 110}
#
# type: FN, Annotation = PERSON, prediction = O, Token = Victoria, Full text = I'm so jealous! said Bárður to Victoria, Metadata = {'Gender': 'female', 'NameSet': 'Danish', 'Country': 'Cameroon', 'Lowercase': False, 'Template#': 93}
#
# type: FN, Annotation = ORG, prediction = O, Token = 10,000, Full text = Sölvi Salómonsson from 10,000 Auto Parts is the keynote speaker, Metadata = {'Gender': 'male', 'NameSet': 'Icelandic', 'Country': 'Ukraine', 'Lowercase': False, 'Template#': 82}
#
# type: FN, Annotation = ORG, prediction = O, Token = Auto, Full text = Sölvi Salómonsson from 10,000 Auto Parts is the keynote speaker, Metadata = {'Gender': 'male', 'NameSet': 'Icelandic', 'Country': 'Ukraine', 'Lowercase': False, 'Template#': 82}
#
# type: FN, Annotation = ORG, prediction = O, Token = Parts, Full text = Sölvi Salómonsson from 10,000 Auto Parts is the keynote speaker, Metadata = {'Gender': 'male', 'NameSet': 'Icelandic', 'Country': 'Ukraine', 'Lowercase': False, 'Template#': 82}
#
# type: FN, Annotation = GPE, prediction = O, Token = ΛΑΡΝΑΚΑ, Full text = card number 5137226842425650 is lost, can you please send a new one to Σουνίου 121, ΛΑΡΝΑΚΑ 6014 i am in ΛΑΡΝΑΚΑ for a business trip, Metadata = {'Gender': 'male', 'NameSet': 'Japanese (Anglicized)', 'Country': 'Senegal', 'Lowercase': False, 'Template#': 29}
#
# type: FN, Annotation = ORG, prediction = O, Token = i., Full text = mission statement: this non-profit founded by radio executives "serves as an advocate for the value of music" and "supports its songwriters, composers and publishers by taking care of an important aspect of their careers â€“ getting paid," according to the i. magnin website. they offer blanket music licenses to businesses and organizations that allow them to play nearly 13 million musical works., Metadata = {'Gender': 'female', 'NameSet': 'Dutch', 'Country': 'Morocco', 'Lowercase': True, 'Template#': 114}
#
# type: FN, Annotation = ORG, prediction = O, Token = magnin, Full text = mission statement: this non-profit founded by radio executives "serves as an advocate for the value of music" and "supports its songwriters, composers and publishers by taking care of an important aspect of their careers â€“ getting paid," according to the i. magnin website. they offer blanket music licenses to businesses and organizations that allow them to play nearly 13 million musical works., Metadata = {'Gender': 'female', 'NameSet': 'Dutch', 'Country': 'Morocco', 'Lowercase': True, 'Template#': 114}
#
# type: FN, Annotation = GPE, prediction = O, Token = ul, Full text = how do i change my address to ul. pck 125, jastrzębie-zdrój 44-335 for post mail?, Metadata = {'Gender': 'male', 'NameSet': 'American', 'Country': 'Nepal', 'Lowercase': True, 'Template#': 27}
#
# type: FN, Annotation = GPE, prediction = O, Token = ., Full text = how do i change my address to ul. pck 125, jastrzębie-zdrój 44-335 for post mail?, Metadata = {'Gender': 'male', 'NameSet': 'American', 'Country': 'Nepal', 'Lowercase': True, 'Template#': 27}
#
# type: FN, Annotation = GPE, prediction = O, Token = pck, Full text = how do i change my address to ul. pck 125, jastrzębie-zdrój 44-335 for post mail?, Metadata = {'Gender': 'male', 'NameSet': 'American', 'Country': 'Nepal', 'Lowercase': True, 'Template#': 27}
#
# type: FN, Annotation = GPE, prediction = O, Token = 125, Full text = how do i change my address to ul. pck 125, jastrzębie-zdrój 44-335 for post mail?, Metadata = {'Gender': 'male', 'NameSet': 'American', 'Country': 'Nepal', 'Lowercase': True, 'Template#': 27}
#
# type: FN, Annotation = GPE, prediction = O, Token = ,, Full text = how do i change my address to ul. pck 125, jastrzębie-zdrój 44-335 for post mail?, Metadata = {'Gender': 'male', 'NameSet': 'American', 'Country': 'Nepal', 'Lowercase': True, 'Template#': 27}
#
# type: FN, Annotation = GPE, prediction = O, Token = jastrzębie, Full text = how do i change my address to ul. pck 125, jastrzębie-zdrój 44-335 for post mail?, Metadata = {'Gender': 'male', 'NameSet': 'American', 'Country': 'Nepal', 'Lowercase': True, 'Template#': 27}
#
# type: FN, Annotation = GPE, prediction = O, Token = -, Full text = how do i change my address to ul. pck 125, jastrzębie-zdrój 44-335 for post mail?, Metadata = {'Gender': 'male', 'NameSet': 'American', 'Country': 'Nepal', 'Lowercase': True, 'Template#': 27}
#
# type: FN, Annotation = GPE, prediction = O, Token = zdrój, Full text = how do i change my address to ul. pck 125, jastrzębie-zdrój 44-335 for post mail?, Metadata = {'Gender': 'male', 'NameSet': 'American', 'Country': 'Nepal', 'Lowercase': True, 'Template#': 27}
#
# type: FN, Annotation = GPE, prediction = O, Token = 44, Full text = how do i change my address to ul. pck 125, jastrzębie-zdrój 44-335 for post mail?, Metadata = {'Gender': 'male', 'NameSet': 'American', 'Country': 'Nepal', 'Lowercase': True, 'Template#': 27}
#
# type: FN, Annotation = GPE, prediction = O, Token = -, Full text = how do i change my address to ul. pck 125, jastrzębie-zdrój 44-335 for post mail?, Metadata = {'Gender': 'male', 'NameSet': 'American', 'Country': 'Nepal', 'Lowercase': True, 'Template#': 27}
#
# type: FN, Annotation = GPE, prediction = O, Token = 335, Full text = how do i change my address to ul. pck 125, jastrzębie-zdrój 44-335 for post mail?, Metadata = {'Gender': 'male', 'NameSet': 'American', 'Country': 'Nepal', 'Lowercase': True, 'Template#': 27}
#
# type: FN, Annotation = ORG, prediction = O, Token = Dun, Full text = Dun Rite Lawn Care is the brainchild of our 3 founders: Charlotte Park, Oline Mikaelsen and Brodie Walker.  The idea was born (on the beach) while they were constructing a website to be the basis of another start-up idea., Metadata = {'Gender': 'male', 'NameSet': 'Scottish', 'Country': 'Asia', 'Lowercase': False, 'Template#': 117}
#
# type: FN, Annotation = ORG, prediction = O, Token = Rite, Full text = Dun Rite Lawn Care is the brainchild of our 3 founders: Charlotte Park, Oline Mikaelsen and Brodie Walker.  The idea was born (on the beach) while they were constructing a website to be the basis of another start-up idea., Metadata = {'Gender': 'male', 'NameSet': 'Scottish', 'Country': 'Asia', 'Lowercase': False, 'Template#': 117}
#
# type: FN, Annotation = ORG, prediction = O, Token = Lawn, Full text = Dun Rite Lawn Care is the brainchild of our 3 founders: Charlotte Park, Oline Mikaelsen and Brodie Walker.  The idea was born (on the beach) while they were constructing a website to be the basis of another start-up idea., Metadata = {'Gender': 'male', 'NameSet': 'Scottish', 'Country': 'Asia', 'Lowercase': False, 'Template#': 117}
#
# type: FN, Annotation = ORG, prediction = O, Token = Care, Full text = Dun Rite Lawn Care is the brainchild of our 3 founders: Charlotte Park, Oline Mikaelsen and Brodie Walker.  The idea was born (on the beach) while they were constructing a website to be the basis of another start-up idea., Metadata = {'Gender': 'male', 'NameSet': 'Scottish', 'Country': 'Asia', 'Lowercase': False, 'Template#': 117}
#
# type: Wrong entity, Annotation = PERSON, prediction = GPE, Token = Charlotte, Full text = Dun Rite Lawn Care is the brainchild of our 3 founders: Charlotte Park, Oline Mikaelsen and Brodie Walker.  The idea was born (on the beach) while they were constructing a website to be the basis of another start-up idea., Metadata = {'Gender': 'male', 'NameSet': 'Scottish', 'Country': 'Asia', 'Lowercase': False, 'Template#': 117}
#
# type: Wrong entity, Annotation = PERSON, prediction = GPE, Token = Park, Full text = Dun Rite Lawn Care is the brainchild of our 3 founders: Charlotte Park, Oline Mikaelsen and Brodie Walker.  The idea was born (on the beach) while they were constructing a website to be the basis of another start-up idea., Metadata = {'Gender': 'male', 'NameSet': 'Scottish', 'Country': 'Asia', 'Lowercase': False, 'Template#': 117}
#
# type: FP, Annotation = O, prediction = GPE, Token = ,, Full text = Dun Rite Lawn Care is the brainchild of our 3 founders: Charlotte Park, Oline Mikaelsen and Brodie Walker.  The idea was born (on the beach) while they were constructing a website to be the basis of another start-up idea., Metadata = {'Gender': 'male', 'NameSet': 'Scottish', 'Country': 'Asia', 'Lowercase': False, 'Template#': 117}
#
# type: Wrong entity, Annotation = PERSON, prediction = GPE, Token = Oline, Full text = Dun Rite Lawn Care is the brainchild of our 3 founders: Charlotte Park, Oline Mikaelsen and Brodie Walker.  The idea was born (on the beach) while they were constructing a website to be the basis of another start-up idea., Metadata = {'Gender': 'male', 'NameSet': 'Scottish', 'Country': 'Asia', 'Lowercase': False, 'Template#': 117}
#
# type: Wrong entity, Annotation = PERSON, prediction = GPE, Token = Mikaelsen, Full text = Dun Rite Lawn Care is the brainchild of our 3 founders: Charlotte Park, Oline Mikaelsen and Brodie Walker.  The idea was born (on the beach) while they were constructing a website to be the basis of another start-up idea., Metadata = {'Gender': 'male', 'NameSet': 'Scottish', 'Country': 'Asia', 'Lowercase': False, 'Template#': 117}
#
# type: FP, Annotation = O, prediction = GPE, Token = and, Full text = Dun Rite Lawn Care is the brainchild of our 3 founders: Charlotte Park, Oline Mikaelsen and Brodie Walker.  The idea was born (on the beach) while they were constructing a website to be the basis of another start-up idea., Metadata = {'Gender': 'male', 'NameSet': 'Scottish', 'Country': 'Asia', 'Lowercase': False, 'Template#': 117}
#
# type: Wrong entity, Annotation = PERSON, prediction = GPE, Token = Brodie, Full text = Dun Rite Lawn Care is the brainchild of our 3 founders: Charlotte Park, Oline Mikaelsen and Brodie Walker.  The idea was born (on the beach) while they were constructing a website to be the basis of another start-up idea., Metadata = {'Gender': 'male', 'NameSet': 'Scottish', 'Country': 'Asia', 'Lowercase': False, 'Template#': 117}
#
# type: Wrong entity, Annotation = PERSON, prediction = GPE, Token = Walker, Full text = Dun Rite Lawn Care is the brainchild of our 3 founders: Charlotte Park, Oline Mikaelsen and Brodie Walker.  The idea was born (on the beach) while they were constructing a website to be the basis of another start-up idea., Metadata = {'Gender': 'male', 'NameSet': 'Scottish', 'Country': 'Asia', 'Lowercase': False, 'Template#': 117}
#
# type: FP, Annotation = O, prediction = GPE, Token = ., Full text = Dun Rite Lawn Care is the brainchild of our 3 founders: Charlotte Park, Oline Mikaelsen and Brodie Walker.  The idea was born (on the beach) while they were constructing a website to be the basis of another start-up idea., Metadata = {'Gender': 'male', 'NameSet': 'Scottish', 'Country': 'Asia', 'Lowercase': False, 'Template#': 117}
#
# type: FP, Annotation = O, prediction = GPE, Token =  , Full text = Dun Rite Lawn Care is the brainchild of our 3 founders: Charlotte Park, Oline Mikaelsen and Brodie Walker.  The idea was born (on the beach) while they were constructing a website to be the basis of another start-up idea., Metadata = {'Gender': 'male', 'NameSet': 'Scottish', 'Country': 'Asia', 'Lowercase': False, 'Template#': 117}
#
# type: FN, Annotation = GPE, prediction = O, Token = 23, Full text = How do I change my address to 23 Settlement Road, WINNINDOO 3858 for post mail?, Metadata = {'Gender': 'male', 'NameSet': 'Croatian', 'Country': 'Tunisia', 'Lowercase': False, 'Template#': 27}
#
# type: FN, Annotation = GPE, prediction = O, Token = Settlement, Full text = How do I change my address to 23 Settlement Road, WINNINDOO 3858 for post mail?, Metadata = {'Gender': 'male', 'NameSet': 'Croatian', 'Country': 'Tunisia', 'Lowercase': False, 'Template#': 27}
#
# type: FN, Annotation = GPE, prediction = O, Token = Road, Full text = How do I change my address to 23 Settlement Road, WINNINDOO 3858 for post mail?, Metadata = {'Gender': 'male', 'NameSet': 'Croatian', 'Country': 'Tunisia', 'Lowercase': False, 'Template#': 27}
#
# type: FN, Annotation = GPE, prediction = O, Token = ,, Full text = How do I change my address to 23 Settlement Road, WINNINDOO 3858 for post mail?, Metadata = {'Gender': 'male', 'NameSet': 'Croatian', 'Country': 'Tunisia', 'Lowercase': False, 'Template#': 27}
#
# type: FN, Annotation = GPE, prediction = O, Token = WINNINDOO, Full text = How do I change my address to 23 Settlement Road, WINNINDOO 3858 for post mail?, Metadata = {'Gender': 'male', 'NameSet': 'Croatian', 'Country': 'Tunisia', 'Lowercase': False, 'Template#': 27}
#
# type: FN, Annotation = GPE, prediction = O, Token = 3858, Full text = How do I change my address to 23 Settlement Road, WINNINDOO 3858 for post mail?, Metadata = {'Gender': 'male', 'NameSet': 'Croatian', 'Country': 'Tunisia', 'Lowercase': False, 'Template#': 27}
#
# type: FN, Annotation = ORG, prediction = O, Token = Modern, Full text = I work for Modern Realty, Metadata = {'Gender': 'male', 'NameSet': 'Russian', 'Country': 'North Korea', 'Lowercase': False, 'Template#': 81}
#
# type: Wrong entity, Annotation = ORG, prediction = PERSON, Token = Realty, Full text = I work for Modern Realty, Metadata = {'Gender': 'male', 'NameSet': 'Russian', 'Country': 'North Korea', 'Lowercase': False, 'Template#': 81}
#
# type: FP, Annotation = O, prediction = GPE, Token = for, Full text = Please update billing addrress with Tekniikantie 8, PUNKAHARJU 58450 for this card: 5279257345280449, Metadata = {'Gender': 'male', 'NameSet': 'Chechen (Latin)', 'Country': 'Pakistan', 'Lowercase': False, 'Template#': 8}
#
# type: FP, Annotation = O, prediction = GPE, Token = this, Full text = Please update billing addrress with Tekniikantie 8, PUNKAHARJU 58450 for this card: 5279257345280449, Metadata = {'Gender': 'male', 'NameSet': 'Chechen (Latin)', 'Country': 'Pakistan', 'Lowercase': False, 'Template#': 8}
#
# type: FP, Annotation = O, prediction = GPE, Token = card, Full text = Please update billing addrress with Tekniikantie 8, PUNKAHARJU 58450 for this card: 5279257345280449, Metadata = {'Gender': 'male', 'NameSet': 'Chechen (Latin)', 'Country': 'Pakistan', 'Lowercase': False, 'Template#': 8}
#
# type: FP, Annotation = O, prediction = GPE, Token = :, Full text = Please update billing addrress with Tekniikantie 8, PUNKAHARJU 58450 for this card: 5279257345280449, Metadata = {'Gender': 'male', 'NameSet': 'Chechen (Latin)', 'Country': 'Pakistan', 'Lowercase': False, 'Template#': 8}
#
# type: FP, Annotation = O, prediction = GPE, Token = 5279257345280449, Full text = Please update billing addrress with Tekniikantie 8, PUNKAHARJU 58450 for this card: 5279257345280449, Metadata = {'Gender': 'male', 'NameSet': 'Chechen (Latin)', 'Country': 'Pakistan', 'Lowercase': False, 'Template#': 8}
#
# type: Wrong entity, Annotation = ORG, prediction = PERSON, Token = Buttrey, Full text = I work for Buttrey Food & Drug, Metadata = {'Gender': 'male', 'NameSet': 'Hispanic', 'Country': 'Macedonia', 'Lowercase': False, 'Template#': 81}
#
# type: FN, Annotation = ORG, prediction = O, Token = Food, Full text = I work for Buttrey Food & Drug, Metadata = {'Gender': 'male', 'NameSet': 'Hispanic', 'Country': 'Macedonia', 'Lowercase': False, 'Template#': 81}
#
# type: FN, Annotation = ORG, prediction = O, Token = &, Full text = I work for Buttrey Food & Drug, Metadata = {'Gender': 'male', 'NameSet': 'Hispanic', 'Country': 'Macedonia', 'Lowercase': False, 'Template#': 81}
#
# type: FN, Annotation = ORG, prediction = O, Token = Drug, Full text = I work for Buttrey Food & Drug, Metadata = {'Gender': 'male', 'NameSet': 'Hispanic', 'Country': 'Macedonia', 'Lowercase': False, 'Template#': 81}
#
# type: FP, Annotation = O, prediction = PERSON, Token = NatalinaLucchese@superrito.com, Full text = Please transfer all funds from my account to this hackers' NatalinaLucchese@superrito.com, Metadata = {'Gender': 'female', 'NameSet': 'Italian', 'Country': 'Somalia', 'Lowercase': False, 'Template#': 30}
#
# type: FN, Annotation = GPE, prediction = O, Token = south, Full text = south-america was super fun to visit!, Metadata = {'Gender': 'female', 'NameSet': 'Swedish', 'Country': 'South-America', 'Lowercase': True, 'Template#': 24}
#
# type: FN, Annotation = GPE, prediction = O, Token = -, Full text = south-america was super fun to visit!, Metadata = {'Gender': 'female', 'NameSet': 'Swedish', 'Country': 'South-America', 'Lowercase': True, 'Template#': 24}
#
# type: FN, Annotation = GPE, prediction = O, Token = america, Full text = south-america was super fun to visit!, Metadata = {'Gender': 'female', 'NameSet': 'Swedish', 'Country': 'South-America', 'Lowercase': True, 'Template#': 24}
#
# type: FP, Annotation = O, prediction = PERSON, Token = Pleasures, Full text = For my take on Mr. Wilson, see Guilty Pleasures: 5 Musicians Of The 70s You're Supposed To Hate (But Secretly Love), Metadata = {'Gender': 'male', 'NameSet': 'American', 'Country': 'Latvia', 'Lowercase': False, 'Template#': 95}
#
# type: FN, Annotation = ORG, prediction = O, Token = Second, Full text = Gabrjel Kozłowski from Second Time Around is the keynote speaker, Metadata = {'Gender': 'male', 'NameSet': 'Polish', 'Country': 'Eritrea', 'Lowercase': False, 'Template#': 82}
#
# type: FN, Annotation = ORG, prediction = O, Token = Time, Full text = Gabrjel Kozłowski from Second Time Around is the keynote speaker, Metadata = {'Gender': 'male', 'NameSet': 'Polish', 'Country': 'Eritrea', 'Lowercase': False, 'Template#': 82}
#
# type: FN, Annotation = ORG, prediction = O, Token = Around, Full text = Gabrjel Kozłowski from Second Time Around is the keynote speaker, Metadata = {'Gender': 'male', 'NameSet': 'Polish', 'Country': 'Eritrea', 'Lowercase': False, 'Template#': 82}
#
# type: FP, Annotation = O, prediction = PERSON, Token = Hobbits, Full text = When they weren't singing about Hobbits, satanic felines and interstellar journeys, they were singing about the verses from Marsilius Chenard's Cautionary Tales. Is there a better example of unbridled creativity than early Chenard?, Metadata = {'Gender': 'male', 'NameSet': 'French', 'Country': 'El Salvador', 'Lowercase': False, 'Template#': 101}
#
# type: Wrong entity, Annotation = ORG, prediction = PERSON, Token = Locost, Full text = I work for Locost Accessories, Metadata = {'Gender': 'male', 'NameSet': 'Icelandic', 'Country': 'Kuwait', 'Lowercase': False, 'Template#': 81}
#
# type: Wrong entity, Annotation = ORG, prediction = PERSON, Token = Accessories, Full text = I work for Locost Accessories, Metadata = {'Gender': 'male', 'NameSet': 'Icelandic', 'Country': 'Kuwait', 'Lowercase': False, 'Template#': 81}
#
# type: FN, Annotation = PERSON, prediction = O, Token = tryggvadóttir, Full text = tryggvadóttir spent a year at rogers peet as the assistant to margrét tryggvadóttir, and the following year at big wheel in begonte, which later became movie gallery in 1965., Metadata = {'Gender': 'female', 'NameSet': 'Icelandic', 'Country': 'Greece', 'Lowercase': True, 'Template#': 123}
#
# type: Wrong entity, Annotation = ORG, prediction = PERSON, Token = rogers, Full text = tryggvadóttir spent a year at rogers peet as the assistant to margrét tryggvadóttir, and the following year at big wheel in begonte, which later became movie gallery in 1965., Metadata = {'Gender': 'female', 'NameSet': 'Icelandic', 'Country': 'Greece', 'Lowercase': True, 'Template#': 123}
#
# ...
#
# type: FN, Annotation = GPE, prediction = O, Token = freistädter, Full text = i once lived in ul. nad jarem 22, gdańsk 80-148. i now live in freistädter strasse 61, brenndorf 9122, Metadata = {'Gender': 'male', 'NameSet': 'Chechen (Latin)', 'Country': 'Tajikistan', 'Lowercase': True, 'Template#': 61}
#
# type: FN, Annotation = GPE, prediction = O, Token = strasse, Full text = i once lived in ul. nad jarem 22, gdańsk 80-148. i now live in freistädter strasse 61, brenndorf 9122, Metadata = {'Gender': 'male', 'NameSet': 'Chechen (Latin)', 'Country': 'Tajikistan', 'Lowercase': True, 'Template#': 61}
#
# type: FN, Annotation = GPE, prediction = O, Token = 61, Full text = i once lived in ul. nad jarem 22, gdańsk 80-148. i now live in freistädter strasse 61, brenndorf 9122, Metadata = {'Gender': 'male', 'NameSet': 'Chechen (Latin)', 'Country': 'Tajikistan', 'Lowercase': True, 'Template#': 61}
#
# type: FN, Annotation = GPE, prediction = O, Token = ,, Full text = i once lived in ul. nad jarem 22, gdańsk 80-148. i now live in freistädter strasse 61, brenndorf 9122, Metadata = {'Gender': 'male', 'NameSet': 'Chechen (Latin)', 'Country': 'Tajikistan', 'Lowercase': True, 'Template#': 61}
#
# type: FN, Annotation = GPE, prediction = O, Token = brenndorf, Full text = i once lived in ul. nad jarem 22, gdańsk 80-148. i now live in freistädter strasse 61, brenndorf 9122, Metadata = {'Gender': 'male', 'NameSet': 'Chechen (Latin)', 'Country': 'Tajikistan', 'Lowercase': True, 'Template#': 61}
#
# type: FN, Annotation = GPE, prediction = O, Token = 9122, Full text = i once lived in ul. nad jarem 22, gdańsk 80-148. i now live in freistädter strasse 61, brenndorf 9122, Metadata = {'Gender': 'male', 'NameSet': 'Chechen (Latin)', 'Country': 'Tajikistan', 'Lowercase': True, 'Template#': 61}
#
# type: FN, Annotation = ORG, prediction = O, Token = Life, Full text = The Stephan Sigursteinsson version recorded for Life'S Gold became the first celebrity recording by a classical musician to sell one million copies. The song was awarded the seventh gold disc ever granted., Metadata = {'Gender': 'male', 'NameSet': 'Icelandic', 'Country': 'California', 'Lowercase': False, 'Template#': 110}
#
# type: FN, Annotation = ORG, prediction = O, Token = 'S, Full text = The Stephan Sigursteinsson version recorded for Life'S Gold became the first celebrity recording by a classical musician to sell one million copies. The song was awarded the seventh gold disc ever granted., Metadata = {'Gender': 'male', 'NameSet': 'Icelandic', 'Country': 'California', 'Lowercase': False, 'Template#': 110}
#
# type: FN, Annotation = ORG, prediction = O, Token = Gold, Full text = The Stephan Sigursteinsson version recorded for Life'S Gold became the first celebrity recording by a classical musician to sell one million copies. The song was awarded the seventh gold disc ever granted., Metadata = {'Gender': 'male', 'NameSet': 'Icelandic', 'Country': 'California', 'Lowercase': False, 'Template#': 110}
#
# type: Wrong entity, Annotation = ORG, prediction = PERSON, Token = Locost, Full text = During the 1990s, Locost Accessories invested heavily in new microprocessor designs fostering the rapid growth of the computer industry., Metadata = {'Gender': 'male', 'NameSet': 'German', 'Country': 'Paraguay', 'Lowercase': False, 'Template#': 120}
#
# type: FN, Annotation = ORG, prediction = O, Token = Accessories, Full text = During the 1990s, Locost Accessories invested heavily in new microprocessor designs fostering the rapid growth of the computer industry., Metadata = {'Gender': 'male', 'NameSet': 'German', 'Country': 'Paraguay', 'Lowercase': False, 'Template#': 120}
#
# type: FN, Annotation = ORG, prediction = O, Token = Home, Full text = Celebrating its 10th year in Sopot, Home Centers is a 501(c)3 that invites songwriters from around the world to Texas to share the universal language of music in collaborations designed to bridge cultures, build friendships and cultivate peace., Metadata = {'Gender': 'male', 'NameSet': 'French', 'Country': 'Sunni', 'Lowercase': False, 'Template#': 116}
#
# type: FN, Annotation = ORG, prediction = O, Token = Centers, Full text = Celebrating its 10th year in Sopot, Home Centers is a 501(c)3 that invites songwriters from around the world to Texas to share the universal language of music in collaborations designed to bridge cultures, build friendships and cultivate peace., Metadata = {'Gender': 'male', 'NameSet': 'French', 'Country': 'Sunni', 'Lowercase': False, 'Template#': 116}
#
# type: FP, Annotation = O, prediction = GPE, Token = Texas, Full text = Celebrating its 10th year in Sopot, Home Centers is a 501(c)3 that invites songwriters from around the world to Texas to share the universal language of music in collaborations designed to bridge cultures, build friendships and cultivate peace., Metadata = {'Gender': 'male', 'NameSet': 'French', 'Country': 'Sunni', 'Lowercase': False, 'Template#': 116}
#
# type: FP, Annotation = O, prediction = PERSON, Token = Pleasures, Full text = For my take on Mr. Csonka, see Guilty Pleasures: 5 Musicians Of The 70s You're Supposed To Hate (But Secretly Love), Metadata = {'Gender': 'male', 'NameSet': 'Hungarian', 'Country': 'Estonia', 'Lowercase': False, 'Template#': 95}
#
# type: FN, Annotation = PERSON, prediction = O, Token = jo, Full text = my name is jo van gameren but everyone calls me jo, Metadata = {'Gender': 'female', 'NameSet': 'Dutch', 'Country': 'Africa', 'Lowercase': True, 'Template#': 58}
#
# type: FN, Annotation = PERSON, prediction = O, Token = van, Full text = my name is jo van gameren but everyone calls me jo, Metadata = {'Gender': 'female', 'NameSet': 'Dutch', 'Country': 'Africa', 'Lowercase': True, 'Template#': 58}
#
# type: FN, Annotation = PERSON, prediction = O, Token = gameren, Full text = my name is jo van gameren but everyone calls me jo, Metadata = {'Gender': 'female', 'NameSet': 'Dutch', 'Country': 'Africa', 'Lowercase': True, 'Template#': 58}
#
# type: FN, Annotation = PERSON, prediction = O, Token = jo, Full text = my name is jo van gameren but everyone calls me jo, Metadata = {'Gender': 'female', 'NameSet': 'Dutch', 'Country': 'Africa', 'Lowercase': True, 'Template#': 58}
#
# type: FN, Annotation = PERSON, prediction = O, Token = van, Full text = Susanne Fleischer listed his top 20 songs for Entertainment Weekly and had the balls to list this song at #15. (What did he put at #1 you ask? Answer:"Tube Snake Boogie" by Louelle van den Brandhof â€“ go figure), Metadata = {'Gender': 'female', 'NameSet': 'Dutch', 'Country': 'Czech Republic', 'Lowercase': False, 'Template#': 103}
#
# type: FN, Annotation = PERSON, prediction = O, Token = den, Full text = Susanne Fleischer listed his top 20 songs for Entertainment Weekly and had the balls to list this song at #15. (What did he put at #1 you ask? Answer:"Tube Snake Boogie" by Louelle van den Brandhof â€“ go figure), Metadata = {'Gender': 'female', 'NameSet': 'Dutch', 'Country': 'Czech Republic', 'Lowercase': False, 'Template#': 103}
#
# type: Wrong entity, Annotation = GPE, prediction = PERSON, Token = Brandenburgische, Full text = May I request to have the statement sent to Brandenburgische Straße 58, Berlin Lichtenrade 12107?, Metadata = {'Gender': 'female', 'NameSet': 'Chechen (Latin)', 'Country': 'Gambia', 'Lowercase': False, 'Template#': 38}
#
# type: Wrong entity, Annotation = GPE, prediction = PERSON, Token = Straße, Full text = May I request to have the statement sent to Brandenburgische Straße 58, Berlin Lichtenrade 12107?, Metadata = {'Gender': 'female', 'NameSet': 'Chechen (Latin)', 'Country': 'Gambia', 'Lowercase': False, 'Template#': 38}
#
# type: FN, Annotation = GPE, prediction = O, Token = 58, Full text = May I request to have the statement sent to Brandenburgische Straße 58, Berlin Lichtenrade 12107?, Metadata = {'Gender': 'female', 'NameSet': 'Chechen (Latin)', 'Country': 'Gambia', 'Lowercase': False, 'Template#': 38}
#
# type: FN, Annotation = GPE, prediction = O, Token = ,, Full text = May I request to have the statement sent to Brandenburgische Straße 58, Berlin Lichtenrade 12107?, Metadata = {'Gender': 'female', 'NameSet': 'Chechen (Latin)', 'Country': 'Gambia', 'Lowercase': False, 'Template#': 38}
#
# type: FN, Annotation = GPE, prediction = O, Token = Berlin, Full text = May I request to have the statement sent to Brandenburgische Straße 58, Berlin Lichtenrade 12107?, Metadata = {'Gender': 'female', 'NameSet': 'Chechen (Latin)', 'Country': 'Gambia', 'Lowercase': False, 'Template#': 38}
#
# type: FN, Annotation = GPE, prediction = O, Token = Lichtenrade, Full text = May I request to have the statement sent to Brandenburgische Straße 58, Berlin Lichtenrade 12107?, Metadata = {'Gender': 'female', 'NameSet': 'Chechen (Latin)', 'Country': 'Gambia', 'Lowercase': False, 'Template#': 38}
#
# type: FN, Annotation = GPE, prediction = O, Token = 12107, Full text = May I request to have the statement sent to Brandenburgische Straße 58, Berlin Lichtenrade 12107?, Metadata = {'Gender': 'female', 'NameSet': 'Chechen (Latin)', 'Country': 'Gambia', 'Lowercase': False, 'Template#': 38}
#
# type: FN, Annotation = GPE, prediction = O, Token = 27, Full text = Not getting bank documents on my addres. Can you please validate the following 27 Alkyon Avenue, Kouklia 8500, Metadata = {'Gender': 'male', 'NameSet': 'Chechen (Latin)', 'Country': 'Bolivia', 'Lowercase': False, 'Template#': 7}
#
# type: Wrong entity, Annotation = GPE, prediction = PERSON, Token = Letališka, Full text = How do I change the address linked to my credit card to Letališka 75, Kobilje 9227?, Metadata = {'Gender': 'male', 'NameSet': 'Russian', 'Country': 'Haiti', 'Lowercase': False, 'Template#': 19}
#
# type: FN, Annotation = GPE, prediction = O, Token = 75, Full text = How do I change the address linked to my credit card to Letališka 75, Kobilje 9227?, Metadata = {'Gender': 'male', 'NameSet': 'Russian', 'Country': 'Haiti', 'Lowercase': False, 'Template#': 19}
#
# type: FN, Annotation = GPE, prediction = O, Token = ,, Full text = How do I change the address linked to my credit card to Letališka 75, Kobilje 9227?, Metadata = {'Gender': 'male', 'NameSet': 'Russian', 'Country': 'Haiti', 'Lowercase': False, 'Template#': 19}
#
# type: FN, Annotation = GPE, prediction = O, Token = Kobilje, Full text = How do I change the address linked to my credit card to Letališka 75, Kobilje 9227?, Metadata = {'Gender': 'male', 'NameSet': 'Russian', 'Country': 'Haiti', 'Lowercase': False, 'Template#': 19}
#
# type: FN, Annotation = GPE, prediction = O, Token = 9227, Full text = How do I change the address linked to my credit card to Letališka 75, Kobilje 9227?, Metadata = {'Gender': 'male', 'NameSet': 'Russian', 'Country': 'Haiti', 'Lowercase': False, 'Template#': 19}
#
# type: FN, Annotation = PERSON, prediction = O, Token = -, Full text = A tribute to Laura Lane-Poole â€“ sadly, she wasn't impressed., Metadata = {'Gender': 'female', 'NameSet': 'Australian', 'Country': 'Solomon Islands', 'Lowercase': False, 'Template#': 100}
#
# type: FN, Annotation = PERSON, prediction = O, Token = Poole, Full text = A tribute to Laura Lane-Poole â€“ sadly, she wasn't impressed., Metadata = {'Gender': 'female', 'NameSet': 'Australian', 'Country': 'Solomon Islands', 'Lowercase': False, 'Template#': 100}
#
# type: FN, Annotation = ORG, prediction = O, Token = The, Full text = During the 1990s, The Flying Bear invested heavily in new microprocessor designs fostering the rapid growth of the computer industry., Metadata = {'Gender': 'male', 'NameSet': 'Japanese (Anglicized)', 'Country': 'Niger', 'Lowercase': False, 'Template#': 120}
#
# type: FN, Annotation = ORG, prediction = O, Token = Flying, Full text = During the 1990s, The Flying Bear invested heavily in new microprocessor designs fostering the rapid growth of the computer industry., Metadata = {'Gender': 'male', 'NameSet': 'Japanese (Anglicized)', 'Country': 'Niger', 'Lowercase': False, 'Template#': 120}
#
# type: FN, Annotation = ORG, prediction = O, Token = Bear, Full text = During the 1990s, The Flying Bear invested heavily in new microprocessor designs fostering the rapid growth of the computer industry., Metadata = {'Gender': 'male', 'NameSet': 'Japanese (Anglicized)', 'Country': 'Niger', 'Lowercase': False, 'Template#': 120}
#
# type: FN, Annotation = ORG, prediction = O, Token = Asian, Full text = Asian Answers songwriter Þórbergur Þorleifsson employs corporate lingo in the first verse of his Harold'S Resignation Letter, Metadata = {'Gender': 'male', 'NameSet': 'Icelandic', 'Country': 'Uzbekistan', 'Lowercase': False, 'Template#': 113}
#
# type: FN, Annotation = ORG, prediction = O, Token = Answers, Full text = Asian Answers songwriter Þórbergur Þorleifsson employs corporate lingo in the first verse of his Harold'S Resignation Letter, Metadata = {'Gender': 'male', 'NameSet': 'Icelandic', 'Country': 'Uzbekistan', 'Lowercase': False, 'Template#': 113}
#
# type: Wrong entity, Annotation = ORG, prediction = PERSON, Token = Harold, Full text = Asian Answers songwriter Þórbergur Þorleifsson employs corporate lingo in the first verse of his Harold'S Resignation Letter, Metadata = {'Gender': 'male', 'NameSet': 'Icelandic', 'Country': 'Uzbekistan', 'Lowercase': False, 'Template#': 113}
#
# type: FN, Annotation = ORG, prediction = O, Token = 'S, Full text = Asian Answers songwriter Þórbergur Þorleifsson employs corporate lingo in the first verse of his Harold'S Resignation Letter, Metadata = {'Gender': 'male', 'NameSet': 'Icelandic', 'Country': 'Uzbekistan', 'Lowercase': False, 'Template#': 113}
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]

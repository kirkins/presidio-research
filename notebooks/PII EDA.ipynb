# %% [markdown]
# ### Fake PII data: Exploratory data analysis
#
# This notebook is used to verify the different fake entities before and after the creation of a synthetic dataset / augmented dataset. First part looks at the generation details and stats, second part evaluates the created synthetic dataset after it has been generated.

# %%
import pandas as pd

from presidio_evaluator.data_generator.extensions import generate_iban, generate_ip_addresses, generate_SSNs, \
    generate_company_names, generate_url, generate_roles, generate_titles, generate_nationality, generate_nation_man, \
    generate_nation_woman, generate_nation_plural, generate_title

from presidio_evaluator.data_generator import FakeDataGenerator, read_synth_dataset

from collections import Counter

import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# 1. Evaluate generation logic and the fake PII bank used during generation

# %%
df = pd.read_csv("../presidio_evaluator/data_generator/raw_data/FakeNameGenerator.com_3000.csv",encoding="utf-8")

# %%
generator = FakeDataGenerator(fake_pii_df=df, 
                              templates=None, 
                              dictionary_path=None,
                              ignore_types={"IP_ADDRESS", 'US_SSN', 'URL','ADDRESS'})
# Out:
# Warning: Dictionary path not provided. Feature `is_in_vocabulary` will be set to False for all samples
# Warning: templates not provided

# %%
pii_df = generator.prep_fake_pii(df)
# Out:
# Preparing fake PII data for ingestion
# Generating roles
# Generating titles
# Generating nationalities
# Generating IBANs
# Generating company names
# Finished preparing fake PII data

# %%
for (name, series) in pii_df.iteritems():
    print(name)
    print("Unique values: {}".format(len(series.unique())))
    print(series.value_counts())
    print("\n**************\n")
# Out:
# Number
# Unique values: 3000
# 2047    1
# 1042    1
# 1060    1
# 1058    1
# 1056    1
#        ..
# 2546    1
# 497     1
# 2544    1
# 495     1
# 2049    1
# Name: Number, Length: 3000, dtype: int64
#
# **************
#
# GENDER
# Unique values: 2
# male      1603
# female    1397
# Name: GENDER, dtype: int64
#
# **************
#
# NameSet
# Unique values: 24
# Russian                  156
# Danish                   143
# England/Wales            141
# Czech                    140
# German                   139
# Hispanic                 133
# Swedish                  133
# Hungarian                132
# Chechen (Latin)          131
# French                   130
# Italian                  128
# Japanese (Anglicized)    128
# American                 127
# Croatian                 123
# Slovenian                123
# Finnish                  122
# Brazil                   114
# Greenland                114
# Dutch                    113
# Polish                   108
# Norwegian                108
# Icelandic                107
# Australian               106
# Scottish                 101
# Name: NameSet, dtype: int64
#
# **************
#
# TITLE
# Unique values: 10
# Mr.           1116
# Mrs.           442
# Ms.            349
# Miss           273
# Dr.            226
# Eng.           161
# Prof.          144
# Professor.     140
# Doctor          76
# Doctor.         73
# Name: TITLE, dtype: int64
#
# **************
#
# FIRST_NAME
# Unique values: 2149
# Marie       13
# Jan          9
# Daniel       9
# Ella         8
# Martin       8
#             ..
# Affiano      1
# Roderick     1
# Kalman       1
# Sölvi        1
# Ludmila      1
# Name: FIRST_NAME, Length: 2149, dtype: int64
#
# **************
#
# MiddleInitial
# Unique values: 37
# M    344
# A    330
# S    228
# K    172
# L    165
# J    163
# C    148
# E    143
# R    142
# T    128
# B    120
# D    115
# N    105
# G     96
# H     96
# P     90
# I     77
# V     74
# F     66
# Z     48
# O     43
# Y     28
# W     21
# U     18
# Á     10
# Þ      8
# Š      6
# X      3
# Q      3
# Ó      2
# É      2
# Đ      1
# Č      1
# Ž      1
# Å      1
# Ö      1
# k      1
# Name: MiddleInitial, dtype: int64
#
# **************
#
# LAST_NAME
# Unique values: 2167
# Hansen         9
# Kristiansen    8
# Johansen       8
# Berg           7
# Souza          7
#               ..
# Sørvik         1
# Neudorf        1
# Šmíd           1
# Zubarev        1
# Doi            1
# Name: LAST_NAME, Length: 2167, dtype: int64
#
# **************
#
# FULL_ADDRESS
# Unique values: 2983
# Ctra. Villena 79       2
# Ilichova 59            2
# Kronwiesenweg 95       2
# 45 rue Pierre Motte    2
# Ilichova 26            2
#                       ..
# Hlíðarvegur 97         1
# ul. Dawida Jana 124    1
# Dalmatinova 37         1
# P.O. Box 107           1
# Liini 22               1
# Name: FULL_ADDRESS, Length: 2983, dtype: int64
#
# **************
#
# CITY
# Unique values: 2404
# København K           27
# Reykjavík             17
# Warszawa              15
# ΛΕΥΚΩΣΙΑ              14
# Ljubljana             13
#                       ..
# Halle                  1
# El Hoyo de Pinares     1
# VALENCIENNES           1
# Maia                   1
# Brits                  1
# Name: CITY, Length: 2404, dtype: int64
#
# **************
#
# State
# Unique values: 254
# LI    85
# PA    80
# NI    73
# SJ    69
# NO    50
#       ..
# CN     1
# CL     1
# AN     1
# ID     1
# CC     1
# Name: State, Length: 253, dtype: int64
#
# **************
#
# StateFull
# Unique values: 416
# Region Sjælland    63
# Nicosia            35
# Λευκωσία           34
# Ontario            33
# São Paulo          31
#                    ..
# Whakatane           1
# Tarragona           1
# Κερύvεια            1
# Alessandria         1
# Enna                1
# Name: StateFull, Length: 415, dtype: int64
#
# **************
#
# ZIP
# Unique values: 2633
# 3915     7
# 9010     6
# 3952     5
# 70002    5
# 3040     5
#         ..
# 78100    1
# 2620     1
# 9908     1
# 6800     1
# 8011     1
# Name: ZIP, Length: 2633, dtype: int64
#
# **************
#
# Country
# Unique values: 30
# CY    194
# EE    122
# ES    112
# NO    106
# TN    106
# DK    106
# IS    105
# US    103
# AT    103
# SI    102
# CH    102
# PL    100
# FI    100
# NL     99
# BE     97
# HU     97
# ZA     94
# CZ     93
# SE     93
# NZ     93
# CA     92
# FR     91
# BR     89
# GB     89
# PT     89
# UY     87
# GL     87
# IT     84
# AU     83
# DE     82
# Name: Country, dtype: int64
#
# **************
#
# COUNTRY
# Unique values: 199
# Israel                  34
# Colombia                27
# United Arab Emirates    25
# California              24
# Liechtenstein           24
#                         ..
# America                  8
# Bolivia                  7
# Poland                   7
# Croatia                  6
# Russia                   6
# Name: COUNTRY, Length: 199, dtype: int64
#
# **************
#
# EMAIL
# Unique values: 3000
# HeidbjortOrlygsdottir@fleckens.hu      1
# BardurHartvigsson@teleworm.us          1
# KieraMoran@superrito.com               1
# BentSJespersen@dayrep.com              1
# MarieFrohlichova@jourrapide.com        1
#                                       ..
# LaylaGairbekov@rhyta.com               1
# MartinKarlsen@superrito.com            1
# MajdaJozicaBerlocnik@jourrapide.com    1
# HalaszGreta@armyspy.com                1
# TorbenKKristensen@fleckens.hu          1
# Name: EMAIL, Length: 3000, dtype: int64
#
# **************
#
# Username
# Unique values: 2914
# Writhadece       2
# Shound           2
# Thanneatch       2
# Hismain          2
# Witairsturs      2
#                 ..
# Hintewell1959    1
# Sping1969        1
# Govey1997        1
# Artilegive       1
# Imettences       1
# Name: Username, Length: 2914, dtype: int64
#
# **************
#
# Password
# Unique values: 3000
# eeg3eehooSh     1
# Nohph8quaebo    1
# daphuC2Ie       1
# eezaJuivei4     1
# eeC4tien9       1
#                ..
# Eithei3of0i     1
# iivo8ieKaeN     1
# phahL2eifie     1
# ra7oLief        1
# OoYeif4die      1
# Name: Password, Length: 3000, dtype: int64
#
# **************
#
# BrowserUserAgent
# Unique values: 94
# Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/73.0.3683.103 Safari/537.36                  293
# Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/74.0.3729.131 Safari/537.36                  287
# Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:66.0) Gecko/20100101 Firefox/66.0                                                       236
# Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/74.0.3729.157 Safari/537.36                  146
# Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_4) AppleWebKit/605.1.15 (KHTML, like Gecko) Version/12.1 Safari/605.1.15                111
#                                                                                                                                     ...
# Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/72.0.3626.121 Safari/537.36                     5
# Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/73.0.3683.86 Safari/537.36                               4
# Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/70.0.3538.77 Safari/537.36                               4
# Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.36 Edge/16.16299      4
# Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/73.0.3683.103 Safari/537.36              3
# Name: BrowserUserAgent, Length: 94, dtype: int64
#
# **************
#
# PHONE_NUMBER
# Unique values: 3000
# 971 12 204       1
# 659 495 913      1
# 485 9625         1
# 9593 5081        1
# 87 47 98         1
#                 ..
# 079 4650 2145    1
# 267-970-1527     1
# 032 572 74 60    1
# 077 1053 6554    1
# 040 459 0685     1
# Name: PHONE_NUMBER, Length: 3000, dtype: int64
#
# **************
#
# TelephoneCountryCode
# Unique values: 29
# 1      195
# 357    194
# 372    122
# 34     112
# 216    106
# 47     106
# 45     106
# 354    105
# 43     103
# 386    102
# 41     102
# 48     100
# 358    100
# 31      99
# 32      97
# 36      97
# 27      94
# 420     93
# 46      93
# 64      93
# 33      91
# 44      89
# 351     89
# 55      89
# 299     87
# 598     87
# 39      84
# 61      83
# 49      82
# Name: TelephoneCountryCode, dtype: int64
#
# **************
#
# MothersMaiden
# Unique values: 1941
# Olsen          11
# Johansen        8
# Melo            7
# Almeida         7
# Kristiansen     7
#                ..
# Campbell        1
# Gomiršek        1
# Jakobsson       1
# Månsson         1
# Lewis           1
# Name: MothersMaiden, Length: 1940, dtype: int64
#
# **************
#
# BIRTHDAY
# Unique values: 2795
# 3/25/1980    3
# 1/29/1940    3
# 5/2/1991     3
# 1/17/1985    3
# 11/7/1970    3
#             ..
# 5/30/1984    1
# 5/11/1956    1
# 6/7/1960     1
# 11/3/1974    1
# 12/8/1968    1
# Name: BIRTHDAY, Length: 2795, dtype: int64
#
# **************
#
# Age
# Unique values: 67
# 63    58
# 82    57
# 22    56
# 61    54
# 74    53
#       ..
# 51    37
# 76    37
# 33    36
# 71    34
# 66    29
# Name: Age, Length: 67, dtype: int64
#
# **************
#
# TropicalZodiac
# Unique values: 12
# Aries          280
# Taurus         274
# Cancer         265
# Capricorn      264
# Leo            251
# Aquarius       246
# Scorpio        246
# Gemini         246
# Virgo          239
# Pisces         236
# Libra          229
# Sagittarius    224
# Name: TropicalZodiac, dtype: int64
#
# **************
#
# CCType
# Unique values: 2
# Visa          1508
# MasterCard    1492
# Name: CCType, dtype: int64
#
# **************
#
# CREDIT_CARD
# Unique values: 3000
# 4916185548219488    1
# 5275870307670532    1
# 4916680276109646    1
# 4556503345556784    1
# 5211243470404849    1
#                    ..
# 5216934795249381    1
# 5348077321678060    1
# 5473694708274086    1
# 5175833192672048    1
# 4539860472514685    1
# Name: CREDIT_CARD, Length: 3000, dtype: int64
#
# **************
#
# CVV2
# Unique values: 956
# 546    10
# 134    10
# 200     9
# 391     8
# 325     8
#        ..
# 292     1
# 687     1
# 766     1
# 278     1
# 217     1
# Name: CVV2, Length: 956, dtype: int64
#
# **************
#
# CCExpires
# Unique values: 60
# 1/2021     67
# 5/2024     65
# 11/2023    65
# 5/2021     62
# 8/2024     61
# 1/2020     60
# 12/2021    59
# 12/2023    59
# 9/2024     58
# 3/2024     57
# 3/2020     57
# 9/2023     57
# 12/2020    56
# 11/2021    55
# 3/2023     55
# 1/2024     55
# 7/2020     55
# 4/2023     54
# 4/2024     54
# 1/2022     54
# 7/2022     54
# 11/2024    54
# 5/2020     53
# 4/2021     53
# 2/2022     52
# 10/2022    51
# 12/2024    50
# 8/2022     50
# 5/2022     50
# 9/2022     50
# 10/2020    50
# 8/2020     49
# 12/2022    49
# 3/2021     49
# 7/2023     48
# 7/2024     48
# 6/2020     48
# 2/2020     47
# 4/2022     46
# 11/2022    46
# 3/2022     46
# 10/2023    46
# 2/2023     46
# 6/2022     46
# 7/2021     46
# 8/2023     44
# 5/2023     43
# 10/2021    43
# 8/2021     42
# 6/2023     42
# 9/2021     41
# 2/2021     41
# 1/2023     41
# 9/2020     40
# 4/2020     39
# 10/2024    39
# 2/2024     39
# 11/2020    39
# 6/2024     38
# 6/2021     37
# Name: CCExpires, dtype: int64
#
# **************
#
# NationalID
# Unique values: 1042
# WK48391724        1
# 349 658 229       1
# 272-46-9251       1
# 386-40-6956       1
# 275 726 594       1
#                  ..
# 030874-2016       1
# DA75119938        1
# 859.242.582-46    1
# ZN 16 32 00 D     1
# 9106161415183     1
# Name: NationalID, Length: 1041, dtype: int64
#
# **************
#
# UPS
# Unique values: 3000
# 1Z 577 274 54 9383 053 3    1
# 1Z 024 2F1 49 1022 131 4    1
# 1Z 100 04W 28 4730 028 7    1
# 1Z 57Y 126 90 1679 232 2    1
# 1Z 433 950 96 2193 654 9    1
#                            ..
# 1Z A03 6A9 10 0009 906 0    1
# 1Z 3Y9 739 86 4603 446 0    1
# 1Z A32 672 90 9312 659 0    1
# 1Z 641 500 07 9816 524 6    1
# 1Z 62V 537 60 6738 045 3    1
# Name: UPS, Length: 3000, dtype: int64
#
# **************
#
# WesternUnionMTCN
# Unique values: 3000
# 540882943     1
# 7421053602    1
# 7750395260    1
# 5256797563    1
# 5540160890    1
#              ..
# 2512568999    1
# 2138613617    1
# 6806438565    1
# 4950260388    1
# 7393406976    1
# Name: WesternUnionMTCN, Length: 3000, dtype: int64
#
# **************
#
# MoneyGramMTCN
# Unique values: 3000
# 46901247    1
# 68765814    1
# 88566216    1
# 28689728    1
# 4828479     1
#            ..
# 51399348    1
# 64324275    1
# 67827177    1
# 10881712    1
# 74844161    1
# Name: MoneyGramMTCN, Length: 3000, dtype: int64
#
# **************
#
# Color
# Unique values: 10
# Blue      1382
# Green      435
# Purple     340
# Red        232
# Black      216
# Orange     144
# Brown       79
# Yellow      71
# Silver      53
# White       48
# Name: Color, dtype: int64
#
# **************
#
# OCCUPATION
# Unique values: 1764
# Building cleaning worker                              6
# Chief operating officer                               6
# Legal secretary                                       6
# Ski patrol                                            5
# Truck dispatcher                                      5
#                                                      ..
# Corporate investigator                                1
# Legal nurse consultant                                1
# Development specialist                                1
# Crushing, grinding, and polishing machine operator    1
# Executive editor                                      1
# Name: OCCUPATION, Length: 1764, dtype: int64
#
# **************
#
# Company
# Unique values: 984
# Buehler Foods          9
# Castro Convertibles    9
# Lechters Housewares    9
# Dave Cooks             9
# Food Fair              8
#                       ..
# Gallenkamp             1
# Formula Gray           1
# Lechmere               1
# Zephyr Investments     1
# Electronics Source     1
# Name: Company, Length: 983, dtype: int64
#
# **************
#
# Vehicle
# Unique values: 2620
# 1993 Chevrolet Blazer     4
# 2004 Ford Econoline       4
# 2001 Bentley Arnage       4
# 2006 Chevrolet Lacetti    3
# 2005 Smart ForFour        3
#                          ..
# 2000 GMC Sonoma           1
# 2006 Ford F-250           1
# 2006 Toyota Celica        1
# 2010 Toyota Tacoma        1
# 2007 Fiat Idea            1
# Name: Vehicle, Length: 2620, dtype: int64
#
# **************
#
# DOMAIN_NAME
# Unique values: 2988
# WirelessMortgages.dk       2
# DesMoinesFuneral.dk        2
# HowDangerous.be            2
# AlmostHot.co.za            2
# SolutionBranding.com.ee    2
#                           ..
# CrisisRepair.gl            1
# BroadReport.dk             1
# MouthDisorder.no           1
# PodSocket.fi               1
# CanineTags.co.uk           1
# Name: DOMAIN_NAME, Length: 2988, dtype: int64
#
# **************
#
# BloodType
# Unique values: 8
# O+     1071
# A+      799
# B+      690
# AB+     156
# O-      130
# A-      106
# B-       39
# AB-       9
# Name: BloodType, dtype: int64
#
# **************
#
# Pounds
# Unique values: 660
# 157.5    13
# 215.4    12
# 153.3    12
# 158.8    12
# 176.7    11
#          ..
# 108.5     1
# 139.0     1
# 254.8     1
# 100.5     1
# 240.9     1
# Name: Pounds, Length: 660, dtype: int64
#
# **************
#
# Kilograms
# Unique values: 660
# 71.6     13
# 97.9     12
# 69.7     12
# 72.2     12
# 80.9     11
#          ..
# 63.2      1
# 69.1      1
# 114.6     1
# 48.8      1
# 115.8     1
# Name: Kilograms, Length: 660, dtype: int64
#
# **************
#
# FeetInches
# Unique values: 17
# 5' 7"     404
# 5' 6"     273
# 5' 5"     269
# 5' 9"     257
# 5' 10"    235
# 5' 8"     228
# 6' 0"     197
# 5' 3"     193
# 5' 1"     188
# 5' 4"     154
# 5' 11"    142
# 5' 2"     129
# 6' 2"     108
# 6' 1"      97
# 5' 0"      69
# 4' 11"     34
# 6' 3"      23
# Name: FeetInches, dtype: int64
#
# **************
#
# Centimeters
# Unique values: 41
# 168    151
# 171    148
# 169    132
# 170    124
# 167    122
# 172    116
# 173    112
# 174    111
# 166    103
# 175     87
# 165     87
# 163     80
# 179     80
# 177     80
# 164     79
# 180     76
# 178     75
# 162     74
# 158     71
# 154     69
# 183     69
# 182     69
# 160     69
# 181     66
# 161     65
# 155     60
# 176     59
# 156     59
# 184     59
# 159     59
# 157     58
# 186     52
# 185     45
# 187     44
# 153     44
# 188     38
# 189     26
# 152     25
# 190     23
# 151     23
# 150     11
# Name: Centimeters, dtype: int64
#
# **************
#
# GUID
# Unique values: 3000
# f395d711-812b-4e50-a49d-ecefb381aed0    1
# 8323277e-a173-440e-95ff-de0756748728    1
# c9d19f71-0ff5-413d-9eb7-9f749c35ca76    1
# acdb76cc-ae1e-494c-98d1-b75c05cc4a54    1
# eba2d4aa-3c38-44e2-9be3-e1521772e537    1
#                                        ..
# f9e5a982-daeb-49bb-bb80-d72f6fbdf4f0    1
# fcad7b9a-91c3-4bf6-8627-c2b368a7b834    1
# c5e4f542-92d2-4282-81ac-f34f7cc5509c    1
# a2aa0138-07d3-41e3-b3b7-455d9854e31f    1
# 29a1b736-bc75-4727-8dd6-4a69b69041b8    1
# Name: GUID, Length: 3000, dtype: int64
#
# **************
#
# Latitude
# Unique values: 2999
#  60.402451    2
#  50.556582    1
#  41.360158    1
#  51.268137    1
#  50.299450    1
#              ..
#  46.765928    1
#  47.566955    1
# -34.949753    1
#  50.523078    1
#  61.147237    1
# Name: Latitude, Length: 2999, dtype: int64
#
# **************
#
# Longitude
# Unique values: 3000
# -35.251634     1
#  5.792644      1
#  11.599697     1
#  7.941740      1
#  2.257371      1
#               ..
#  10.757335     1
#  151.318119    1
#  4.564910      1
# -112.733860    1
#  174.762311    1
# Name: Longitude, Length: 3000, dtype: int64
#
# **************
#
# PERSON
# Unique values: 2996
# Pedro Alves               2
# Seweryna Kaczmarek        2
# Khasbulat Shishani        2
# Gerth Rosing              2
# Lukas Riise               1
#                          ..
# Cendrillon Coudert        1
# Soib Batukayev            1
# Jessica Ritter            1
# Shovda Masaev             1
# Selma Sigurvaldadóttir    1
# Name: PERSON, Length: 2996, dtype: int64
#
# **************
#
# DATE
# Unique values: 2795
# 3/25/1980    3
# 1/29/1940    3
# 5/2/1991     3
# 1/17/1985    3
# 11/7/1970    3
#             ..
# 5/30/1984    1
# 5/11/1956    1
# 6/7/1960     1
# 11/3/1974    1
# 12/8/1968    1
# Name: DATE, Length: 2795, dtype: int64
#
# **************
#
# LOCATION
# Unique values: 199
# Israel                  34
# Colombia                27
# United Arab Emirates    25
# Liechtenstein           24
# England                 24
#                         ..
# America                  8
# Poland                   7
# Bolivia                  7
# Croatia                  6
# Russia                   6
# Name: LOCATION, Length: 199, dtype: int64
#
# **************
#
# ROLE
# Unique values: 22
# Attorney                     160
# Vice-president               152
# Accountant                   149
# Journalist                   148
# Chief Information Officer    147
# Chief of staff               141
# Actuary                      141
# CEO                          140
# General Manager              138
# CFO                          137
# President                    137
# Chief Architect              136
# Director                     136
# Manager                      134
# Secretary                    133
# CIO                          133
# Minister                     131
# Operator                     128
# Scientist                    127
# Chief Executive Officer      121
# Prime minister               120
# Engineer                     111
# Name: ROLE, dtype: int64
#
# **************
#
# FEMALE_TITLE
# Unique values: 8
# Mrs.          882
# Ms.           765
# Miss          600
# Doctor        172
# Eng.          157
# Dr.           145
# Prof.         142
# Professor.    137
# Name: FEMALE_TITLE, dtype: int64
#
# **************
#
# MALE_TITLE
# Unique values: 6
# Mr.           2107
# Dr.            285
# Prof.          158
# Eng.           155
# Professor.     148
# Doctor.        147
# Name: MALE_TITLE, dtype: int64
#
# **************
#
# NATIONALITY
# Unique values: 189
# American          89
# British           56
# Emirati           42
# Middle-Eastern    38
# Dutch             32
#                   ..
# Israeli            8
# Zambian            8
# Madagascan         8
# Kurd               8
# Jamaican           7
# Name: NATIONALITY, Length: 189, dtype: int64
#
# **************
#
# NATION_MAN
# Unique values: 189
# Briton            64
# Emirati           48
# American          41
# Us Citizen        39
# Middle-Eastern    34
#                   ..
# Armenian           7
# Kenyan             6
# German             6
# Slovenian          5
# Surinamese         4
# Name: NATION_MAN, Length: 189, dtype: int64
#
# **************
#
# NATION_WOMAN
# Unique values: 189
# American      60
# Briton        50
# Emirati       48
# Dutchwoman    34
# Us Citizen    34
#               ..
# Sri Lankan     7
# Ukrainian      7
# Liberian       6
# Australian     6
# Andorran       6
# Name: NATION_WOMAN, Length: 189, dtype: int64
#
# **************
#
# NATION_PLURAL
# Unique values: 189
# Britons        61
# American       53
# Emiratis       38
# Dutchmans      36
# Dominicans     32
#                ..
# Malaysians      8
# Australians     7
# Mauritians      7
# Nicaraguans     7
# Hungarians      6
# Name: NATION_PLURAL, Length: 189, dtype: int64
#
# **************
#
# IBAN
# Unique values: 1
# IL270126100000000544211    3000
# Name: IBAN, dtype: int64
#
# **************
#
# ORG
# Unique values: 653
# Thomas, Holt and Myers                    11
# Clean Power Finance                       11
# Locavore                                  10
# Farmers                                   10
# Opportunityspace Inc.                     10
#                                           ..
# Compendia Bioscience Life Technologies     1
# Factual                                    1
# Davis, Reynolds and Williamson             1
# Arrive Labs                                1
# Govzilla Inc                               1
# Name: ORG, Length: 653, dtype: int64
#
# **************
#
# ORGANIZATION
# Unique values: 984
# Lechters Housewares          9
# Castro Convertibles          9
# Dave Cooks                   9
# Buehler Foods                9
# Afforda                      8
#                             ..
# Oshman'S                     1
# Big Bear Stores              1
# Square Circle                1
# Perisolution                 1
# Total Network Development    1
# Name: ORGANIZATION, Length: 983, dtype: int64
#
# **************

# %%
from wordcloud import WordCloud

def series_to_wordcloud(series):
    freqs = series.value_counts()
    wordcloud = WordCloud(background_color='white',width=800,height=400).generate_from_frequencies(freqs)
    fig = plt.figure(figsize=(16, 8))
    plt.suptitle("{} word cloud".format(series.name))
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.axis("off")

# %%
series_to_wordcloud(pii_df.FIRST_NAME)

# %%
series_to_wordcloud(pii_df.LAST_NAME)

# %%
series_to_wordcloud(pii_df.COUNTRY)

# %%
series_to_wordcloud(pii_df.ORGANIZATION)

# %%
series_to_wordcloud(pii_df.CITY)

# %% [markdown]
# 2. Evaluate different entities in the synthetic dataset after creation

# %%
synth = read_synth_dataset("../data/generated_size_100_date_February_28_2020.json")

# %%
sentences_only = [(sample.full_text,sample.metadata) for sample in synth]

# %%
sentences_only[2]
# Out:
# ("The Nunzia Nucci version recorded for Luskin'S became the first celebrity recording by a classical musician to sell one million copies. The song was awarded the seventh gold disc ever granted.",
#  {'Gender': 'female',
#   'NameSet': 'Italian',
#   'Country': 'Madagascar',
#   'Lowercase': False,
#   'Template#': 110})

# %%
print("Proportions of female vs. male based samples:")
Counter([sentence[1]['Gender'] for sentence in sentences_only])
# Out:
# Proportions of female vs. male based samples:
# Counter({'male': 48, 'female': 52})

# %%
print("Proportion of lower case samples:")
Counter([sentence[1]['Lowercase'] for sentence in sentences_only])
# Out:
# Proportion of lower case samples:
# Counter({False: 92, True: 8})

# %%
print("Proportion of nameset across samples:")
Counter([sentence[1]['NameSet'] for sentence in sentences_only])
# Out:
# Proportion of nameset across samples:
# Counter({'Japanese (Anglicized)': 3,
#          'England/Wales': 5,
#          'Italian': 8,
#          'Dutch': 7,
#          'Greenland': 5,
#          'Czech': 4,
#          'Danish': 2,
#          'Hungarian': 3,
#          'Russian': 5,
#          'Australian': 3,
#          'Finnish': 4,
#          'Slovenian': 4,
#          'Croatian': 5,
#          'Norwegian': 7,
#          'Icelandic': 3,
#          'Swedish': 2,
#          'Chechen (Latin)': 2,
#          'Hispanic': 6,
#          'American': 8,
#          'Brazil': 5,
#          'Polish': 3,
#          'German': 3,
#          'French': 1,
#          'Scottish': 2})

# %%
def get_entity_values_from_sample(sample,entity_types):
    name_entities = [span.entity_value for span in sample.spans if span.entity_type in entity_types]
    return name_entities
    
names = [get_entity_values_from_sample(sample,['PERSON','FIRST_NAME','LAST_NAME']) for sample in synth]
names = [item for sublist in names for item in sublist]
series_to_wordcloud(pd.Series(names,name='PERSON, FIRST_NAME, LAST_NAME'))

# %%
countries = [get_entity_values_from_sample(sample,['LOCATION']) for sample in synth]
countries = [item for sublist in countries for item in sublist]
series_to_wordcloud(pd.Series(countries,name='LOCATION'))

# %%
orgs = [get_entity_values_from_sample(sample,['ORGANIZATION']) for sample in synth]
orgs = [item for sublist in orgs for item in sublist]
series_to_wordcloud(pd.Series(orgs,name='ORGANIZATION'))
